# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.19.5)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2.10)

# %%
import librosa
from librosa import display

# %%
test_audio_file = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro01/Ses01F_impro01_F000.wav'

# %%
data, sampling_rate = librosa.load(test_audio_file)

# %%
sampling_rate
# Out:
# 22050

# %%
% pylab inline
import os
import pandas as pd
import glob
plt.figure(figsize=(12,4))
librosa.display.waveplot(data,sr=sampling_rate)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['display']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
mfccs = librosa.feature.mfcc(data, sr=sampling_rate)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sampling_rate, x_axis='time')
# Out:
# (20, 84)

# %%
import re

# first test with one file
test_path = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro01.txt'

# %%
file_regex = re.compile(r'\[.+\]\n', re.IGNORECASE)

# %%
with open(test_path) as fptr:
    test_file_content = fptr.read()
    
info_lines = re.findall(file_regex, test_file_content)

# %%
for l in info_lines[1:10]:
    print(l.strip().split('\t'))
# Out:
# ['[6.2901 - 8.2357]', 'Ses01F_impro01_F000', 'neu', '[2.5000, 2.5000, 2.5000]']
# ['[10.0100 - 11.3925]', 'Ses01F_impro01_F001', 'neu', '[2.5000, 2.5000, 2.5000]']
# ['[14.8872 - 18.0175]', 'Ses01F_impro01_F002', 'neu', '[2.5000, 2.5000, 2.5000]']
# ['[19.2900 - 20.7875]', 'Ses01F_impro01_F003', 'xxx', '[2.5000, 3.0000, 3.0000]']
# ['[21.3257 - 24.7400]', 'Ses01F_impro01_F004', 'xxx', '[2.5000, 3.0000, 2.5000]']
# ['[27.4600 - 31.4900]', 'Ses01F_impro01_F005', 'neu', '[2.5000, 3.5000, 2.0000]']
# ['[38.9650 - 43.5900]', 'Ses01F_impro01_F006', 'fru', '[2.0000, 3.5000, 3.5000]']
# ['[46.5800 - 52.1900]', 'Ses01F_impro01_F007', 'fru', '[2.5000, 3.5000, 3.5000]']
# ['[56.1600 - 58.8225]', 'Ses01F_impro01_F008', 'fru', '[2.0000, 3.5000, 3.5000]']

# %%
import re
import os


file_regex = re.compile(r'\[.+\]\n', re.IGNORECASE)

start_times, end_times, wav_file_names, emotions, vals, acts, doms = [], [], [], [], [], [], []

for sess in range(1, 6):
    emo_evaluation_dir = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session{}/dialog/EmoEvaluation/'.format(sess)
    evaluation_files = [l for l in os.listdir(emo_evaluation_dir) if 'Ses' in l]
    for file in evaluation_files:
        with open(emo_evaluation_dir + file) as f:
            content = f.read()
        info_lines = re.findall(file_regex, content)
        for line in info_lines[1:]:  # the first line is a header
            start_end_time, wav_file_name, emotion, val_act_dom = line.strip().split('\t')
            start_time, end_time = start_end_time[1:-1].split('-')
            val, act, dom = val_act_dom[1:-1].split(',')
            val, act, dom = float(val), float(act), float(dom)
            start_time, end_time = float(start_time), float(end_time)
            start_times.append(start_time)
            end_times.append(end_time)
            wav_file_names.append(wav_file_name)
            emotions.append(emotion)
            vals.append(val)
            acts.append(act)
            doms.append(dom)

# %%
import pandas as pd

df_iemocap = pd.DataFrame(columns=['start_time', 'end_time', 'wav_file', 'emotion', 'val', 'act', 'dom'])

df_iemocap['start_time'] = start_times
df_iemocap['end_time'] = end_times
df_iemocap['wav_file'] = wav_file_names
df_iemocap['emotion'] = emotions
df_iemocap['val'] = vals
df_iemocap['act'] = acts
df_iemocap['dom'] = doms

df_iemocap.tail()
# Out:
#        start_time  end_time             wav_file emotion  val  act  dom
# 10034      158.43    161.22  Ses05F_impro01_M020     fru  2.0  3.5  3.5
# 10035      163.35    167.67  Ses05F_impro01_M021     fru  2.0  3.5  4.0
# 10036      168.59    170.81  Ses05F_impro01_M022     xxx  3.0  3.5  4.0
# 10037      173.52    179.84  Ses05F_impro01_M023     fru  2.0  4.0  4.5
# 10038      181.24    184.62  Ses05F_impro01_M024     xxx  4.0  3.5  3.5

# %%
df_iemocap.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/df_iemocap.csv', index=False)

# %%
### Audio files

# %%
# Try for one file first
import librosa
import os
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as ms
from tqdm import tqdm
import pickle

import IPython.display
import librosa.display
ms.use('seaborn-muted')
# %matplotlib inline

# %%
test_file_path = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session1/dialog/wav/Ses01F_impro01.wav'

y, sr = librosa.load(test_file_path, sr=44100)
y, sr
# Out:
# (array([ 0.42572615,  0.48587543,  0.37312022, ..., -0.31514615,
#         -0.16263676,  0.        ], dtype=float32), 44100)

# %%
import pandas as pd
import math

labels_df = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/df_iemocap.csv')
iemocap_dir = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/'

# %%
sr = 44100
audio_vectors = {}
for sess in [5]:  # using one session due to memory constraint, can replace [5] with range(1, 6)
    wav_file_path = '{}Session{}/dialog/wav/'.format(iemocap_dir, sess)
    orig_wav_files = os.listdir(wav_file_path)
    for orig_wav_file in tqdm(orig_wav_files):
        try:
            orig_wav_vector, _sr = librosa.load(wav_file_path + orig_wav_file, sr=sr)
            orig_wav_file, file_format = orig_wav_file.split('.')
            for index, row in labels_df[labels_df['wav_file'].str.contains(orig_wav_file)].iterrows():
                start_time, end_time, truncated_wav_file_name, emotion, val, act, dom = row['start_time'], row['end_time'], row['wav_file'], row['emotion'], row['val'], row['act'], row['dom']
                start_frame = math.floor(start_time * sr)
                end_frame = math.floor(end_time * sr)
                truncated_wav_vector = orig_wav_vector[start_frame:end_frame + 1]
                audio_vectors[truncated_wav_file_name] = truncated_wav_vector
        except:
            print('An exception occured for {}'.format(orig_wav_file))
    with open('/content/drive/My Drive/IEMOCAP/pre-processed/audio_vectors_{}.pkl'.format(sess), 'wb') as f:
        pickle.dump(audio_vectors, f)
# Out:
# 100%|██████████| 31/31 [06:35<00:00, 12.75s/it]

# %%
# sess = 5
# with open('/content/drive/My Drive/IEMOCAP/pre-processed/audio_vectors_{}.pkl'.format(sess), 'wb') as f:
#         pickle.dump(audio_vectors, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8c05360b6955> in <module>()
#       1 sess = 5
#       2 with open('/content/drive/My Drive/IEMOCAP/pre-processed/audio_vectors_{}.pkl'.format(sess), 'wb') as f:
# ----> 3         pickle.dump(audio_vectors, f)
#
# NameError: name 'audio_vectors' is not defined

# %%
import os
import pickle
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as ms
from tqdm import tqdm
import librosa
import math
import random
import pandas as pd
import IPython.display
import librosa.display
ms.use('seaborn-muted')
# %matplotlib inline

# %%
# !pip install opensmile --upgrade
# Out:
# Requirement already satisfied: opensmile in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: audobject<0.6.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from opensmile) (0.5.0)
# Requirement already satisfied: audinterface<0.9.0,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from opensmile) (0.7.0)
# Requirement already satisfied: audformat<2.0.0,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from audinterface<0.9.0,>=0.7.0->opensmile) (0.11.6)
# Requirement already satisfied: audresample<0.3.0,>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from audinterface<0.9.0,>=0.7.0->opensmile) (0.1.6)
# Requirement already satisfied: pandas<1.3,>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.1.5)
# Requirement already satisfied: iso-639 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (0.4.5)
# Requirement already satisfied: audeer<2.0.0,>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.0)
# Requirement already satisfied: audiofile>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from audeer<2.0.0,>=1.8.0->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (4.62.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (0.10.3.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.19.5)
# Requirement already satisfied: sox in /usr/local/lib/python3.7/dist-packages (from audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3,>=1.1.5->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3,>=1.1.5->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<1.3,>=1.1.5->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from oyaml->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (3.13)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->audiofile>=0.4.0->audformat<2.0.0,>=0.10.1->audinterface<0.9.0,>=0.7.0->opensmile) (2.20)

# %%
data_dir = '/content/drive/My Drive/IEMOCAP/pre-processed/'
labels_df_path = '{}df_iemocap.csv'.format(data_dir)
audio_vectors_path = '{}audio_vectors_1.pkl'.format(data_dir)

# %%
labels_df = pd.read_csv(labels_df_path)
audio_vectors = pickle.load(open(audio_vectors_path, 'rb'))

# %%
random_file_name = list(audio_vectors.keys())[random.choice(range(len(audio_vectors.keys())))]
y = audio_vectors[random_file_name]
sr = 44100

# %%
plt.figure(figsize=(15,2))
librosa.display.waveplot(y, sr=sr, max_sr=1000, alpha=0.25, color='r')

# %%
# !pip install sox --upgrade
# Out:
# Requirement already satisfied: sox in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from sox) (1.19.5)

# %%
# !apt -qq install -y sox
# Out:
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 37 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,717 kB of additional disk space will be used.
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../5-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../6-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../7-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...

# %%
import opensmile
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
test_opensmile_file_path = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session1/sentences/wav/Ses01F_impro01/Ses01F_impro01_F000.wav'

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import joblib

# %%
#test_opensmile_df = smile.process_files(test_opensmile_file_path)
test_opensmile_df = smile.process_files(test_audio_file)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sox/core.py in soxi(filepath, argument)
#     148             args,
# --> 149             stderr=subprocess.PIPE
#     150         )
#
# /usr/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# /usr/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['sox', '--i', '-c', '/']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# SoxiError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/audiofile/core/convert.py in convert_to_wav(infile, outfile, offset, duration)
#      40         # Convert to WAV file with sox
# ---> 41         run_sox(infile, outfile, offset, duration)
#      42     except (sox.core.SoxError, sox.core.SoxiError):
#
# /usr/local/lib/python3.7/dist-packages/audiofile/core/utils.py in run_sox(infile, outfile, offset, duration)
#      42         tfm.trim(offset)
# ---> 43     tfm.build(infile, outfile)
#      44
#
# /usr/local/lib/python3.7/dist-packages/sox/transform.py in build(self, input_filepath, output_filepath, input_array, sample_rate_in, extra_args, return_output)
#     593         input_format, input_filepath = self._parse_inputs(
# --> 594             input_filepath, input_array, sample_rate_in
#     595         )
#
# /usr/local/lib/python3.7/dist-packages/sox/transform.py in _parse_inputs(self, input_filepath, input_array, sample_rate_in)
#     495             if input_format.get('channels') is None:
# --> 496                 input_format['channels'] = file_info.channels(input_filepath)
#     497         elif input_array is not None:
#
# /usr/local/lib/python3.7/dist-packages/sox/file_info.py in channels(input_filepath)
#      81     validate_input_file(input_filepath)
# ---> 82     output = soxi(input_filepath, 'c')
#      83     return int(output)
#
# /usr/local/lib/python3.7/dist-packages/sox/core.py in soxi(filepath, argument)
#     152         logger.info("SoXI error message: {}".format(cpe.output))
# --> 153         raise SoxiError("SoXI failed with exit code {}".format(cpe.returncode))
#     154
#
# SoxiError: SoXI failed with exit code 1
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-26-8e860d62a158> in <module>()
#       1 #test_opensmile_df = smile.process_files(test_opensmile_file_path)
# ----> 2 test_opensmile_df = smile.process_files(test_audio_file)
#
# /usr/local/lib/python3.7/dist-packages/audinterface/core/feature.py in process_files(self, files, starts, ends, root)
#     244             starts=starts,
#     245             ends=ends,
# --> 246             root=root,
#     247         )
#     248         return self._series_to_frame(series)
#
# /usr/local/lib/python3.7/dist-packages/audinterface/core/process.py in process_files(self, files, starts, ends, root)
#     229             multiprocessing=self.multiprocessing,
#     230             progress_bar=verbose,
# --> 231             task_description=f'Process {len(files)} files',
#     232         )
#     233         self.verbose = verbose
#
# /usr/local/lib/python3.7/dist-packages/audeer/core/utils.py in run_tasks(task_func, params, num_workers, multiprocessing, progress_bar, task_description)
#     442         ) as pbar:
#     443             for index, param in enumerate(pbar):
# --> 444                 results[index] = task_func(*param[0], **param[1])
#     445
#     446     else:  # parallel
#
# /usr/local/lib/python3.7/dist-packages/audinterface/core/process.py in process_file(self, file, start, end, root)
#     171             return self._process_index_wo_segment(index, root)
#     172         else:
# --> 173             return self._process_file(file, start=start, end=end, root=root)
#     174
#     175     def process_files(
#
# /usr/local/lib/python3.7/dist-packages/audinterface/core/process.py in _process_file(self, file, start, end, root)
#     112             start=start,
#     113             end=end,
# --> 114             root=root,
#     115         )
#     116         y = self._process_signal(
#
# /usr/local/lib/python3.7/dist-packages/audinterface/core/utils.py in read_audio(file, start, end, root)
#     135         always_2d=True,
#     136         offset=offset,
# --> 137         duration=duration,
#     138     )
#     139
#
# /usr/local/lib/python3.7/dist-packages/audiofile/core/io.py in read(file, duration, offset, always_2d, dtype, **kwargs)
#      72         with tempfile.TemporaryDirectory(prefix='audiofile') as tmpdir:
#      73             tmpfile = os.path.join(tmpdir, 'tmp.wav')
# ---> 74             convert_to_wav(file, tmpfile, offset, duration)
#      75             signal, sample_rate = soundfile.read(
#      76                 tmpfile,
#
# /usr/local/lib/python3.7/dist-packages/audiofile/core/convert.py in convert_to_wav(infile, outfile, offset, duration)
#      42     except (sox.core.SoxError, sox.core.SoxiError):
#      43         # Convert to WAV file with ffmpeg
# ---> 44         run_ffmpeg(infile, outfile, offset, duration)
#
# /usr/local/lib/python3.7/dist-packages/audiofile/core/utils.py in run_ffmpeg(infile, outfile, offset, duration)
#      31     else:
#      32         cmd = f'ffmpeg -ss {offset} -i "{infile}" "{outfile}"'
# ---> 33     run(cmd)
#      34
#      35
#
# /usr/local/lib/python3.7/dist-packages/audiofile/core/utils.py in run(shell_command)
#      17     out = subprocess.check_output(
#      18         shlex.split(shell_command),
# ---> 19         stderr=subprocess.STDOUT
#      20     )
#      21     try:
#
# /usr/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#     413
#
# /usr/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         if check and retcode:
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#     514
#
# CalledProcessError: Command '['ffmpeg', '-ss', '0', '-i', '/', '/tmp/audiofileg7ah7vcn/tmp.wav']' returned non-zero exit status 1.

# %%
print('Signal mean = {:.5f}'.format(np.mean(abs(y))))
print('Signal std dev = {:.5f}'.format(np.std(y)))
# Out:
# Signal mean = 0.00371
# Signal std dev = 0.00676

# %%
rmse = librosa.feature.rms(y + 0.0001)[0]
plt.figure(figsize=(15,2))
plt.plot(rmse)
plt.ylabel('RMSE')
print('RMSE mean = {:.5f}'.format(np.mean(rmse)))
print('RMSE std dev = {:.5f}'.format(np.std(rmse)))
# Out:
# RMSE mean = 0.00455
# RMSE std dev = 0.00500

# %%
from IPython.display import Audio
Audio(y, rate=44100)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
silence = 0
for e in rmse:
    if e <= 0.4 * np.mean(rmse):
        silence += 1
print(silence/float(len(rmse)))
# Out:
# 0.2126865671641791

# %%
y_harmonic, y_percussive = librosa.effects.hpss(y)
np.mean(y_harmonic)
# Out:
# -3.5596104e-06

# %%
autocorr = librosa.core.autocorrelate(y)
np.max(autocorr)
# Out:
# 6.269400651818387

# %%
cl = 0.45 * np.mean(abs(y))
center_clipped = []
for s in y:
    if s >= cl:
        center_clipped.append(s - cl)
    elif s <= -cl:
        center_clipped.append(s + cl)
    elif np.abs(s) < cl:
        center_clipped.append(0)
new_autocorr = librosa.core.autocorrelate(np.array(center_clipped))
np.max(new_autocorr)
# Out:
# 4.89180658929507

# %%
audio_vectors[random_file_name]
# Out:
# array([ 0.00057719,  0.00021404, -0.0002088 , ..., -0.00085451,
#        -0.00124261, -0.00163649], dtype=float32)

# %%
y
# Out:
# array([ 0.00057719,  0.00021404, -0.0002088 , ..., -0.00085451,
#        -0.00124261, -0.00163649], dtype=float32)

# %%
mfccs = np.mean(librosa.feature.mfcc(y).T, axis=0)

# %%
mfccs
# Out:
# array([-4.7383975e+02,  1.7908290e+02,  8.9395456e+00,  1.1419808e+01,
#         3.9697136e+01,  4.2036548e+00, -4.8364314e-01,  1.6148804e+01,
#         2.7378013e+00, -2.0801089e+00,  4.6845722e+00, -4.7741146e+00,
#        -7.0543213e+00, -2.0333223e-01, -5.3662848e+00, -5.7449479e+00,
#         1.6047878e+00, -1.9465053e+00, -4.2509694e+00,  1.5543426e+00],
#       dtype=float32)

# %%
stft=np.abs(librosa.stft(y))
chroma=np.mean(librosa.feature.chroma_stft(S=stft).T,axis=0)

# %%
chroma
# Out:
# array([0.6660294 , 0.5394258 , 0.50508094, 0.5457757 , 0.55943096,
#        0.5390243 , 0.5821816 , 0.5533495 , 0.56902295, 0.6300775 ,
#        0.6547953 , 0.7354078 ], dtype=float32)

# %%
mel=np.mean(librosa.feature.melspectrogram(y).T,axis=0)

# %%
mel.shape
# Out:
# (128,)

# %%
result_loc = np.array([])

# %%
result_loc=np.hstack((result_loc, mfccs,chroma,mel))

# %%
result_loc.shape
# Out:
# (160,)

# %%
columns = ['wav_file', 'label', 'sig_mean', 'sig_std', 'rmse_mean', 'rmse_std', 'silence', 'harmonic', 'auto_corr_max', 'auto_corr_std']
df_features = pd.DataFrame(columns=columns)

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'exc': 2,
                'sad': 3,
                'fru': 4,
                'fea': 5,
                'sur': 6,
                'neu': 7,
                'xxx': 8,
                'oth': 8}

data_dir = '/content/drive/My Drive/IEMOCAP/pre-processed/'
labels_path = '{}df_iemocap.csv'.format(data_dir)
audio_vectors_path = '{}audio_vectors_'.format(data_dir)

# %%
def extract_mfcc_chroma_mel(audio_vectors, wav_file, label, mfcc, chroma, mel, sample_rate = 44100):
        if chroma:
            stft=np.abs(librosa.stft(audio_vectors))
        result=np.array([])
        result=np.hstack((result,wav_file,label))
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=audio_vectors, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(audio_vectors, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
        return result

# %%
result_y = extract_mfcc_chroma_mel(y,random_file_name, 1, mfcc=True,chroma=True,mel=True)

# %%
result_y
# Out:
# array(['Ses05M_impro04_F037', '1', '-568.78357', '191.00526',
#        '-25.992203', '34.08573', '40.521854', '-13.200089', '12.631712',
#        '5.6827674', '-12.595137', '8.157385', '0.20900474', '-5.2801013',
#        '7.057604', '-0.54597324', '0.9116143', '6.863115', '-0.11640746',
#        '2.8853893', '3.2010083', '-2.8046515', '-0.054670725',
#        '-1.7035061', '-3.7149928', '-1.1763847', '-4.6251693',
#        '-2.9870856', '1.5228149', '-3.6971982', '-5.3574405',
#        '-0.36368048', '0.8621729', '-0.1156767', '-1.0910646',
#        '-0.53436404', '2.340643', '3.7302332', '3.4962275', '2.4918413',
#        '0.54389596', '-0.6666879', '0.6825953', '0.6545078', '0.64609057',
#        '0.62266237', '0.63482505', '0.676481', '0.66770184', '0.6594964',
#        '0.6598619', '0.7100421', '0.6755878', '0.64546293', '0.01132346',
#        '0.02415531', '0.014387705', '0.022318505', '0.078497425',
#        '0.08659554', '0.06551728', '0.05273176', '0.055482518',
#        '0.030994246', '0.02395972', '0.027985776', '0.041399553',
#        '0.03497312', '0.04149208', '0.041066535', '0.051071923',
#        '0.028136427', '0.0062435884', '0.00762485', '0.0075341533',
#        '0.0040201335', '0.007604128', '0.0036116103', '0.0011863428',
#        '0.0006092846', '0.0012296161', '0.0012784317', '0.0017924277',
#        '0.0012430026', '0.0009124139', '0.00052171794', '0.00019858859',
#        '0.0005499716', '0.0007248088', '0.00036447946', '0.00023212131',
#        '0.00075767783', '0.00064762385', '0.00029559975', '0.00023476417',
#        '0.00057573174', '0.00047792293', '0.00014139278', '0.00014491813',
#        '0.00033241865', '0.00023915741', '0.00018782055', '0.00031085475',
#        '0.00055685674', '0.0004515686', '0.000765089', '0.0012901408',
#        '0.0011681602', '0.0007453535', '0.00054766156', '0.0005327569',
#        '0.00037458696', '0.00033879094', '0.000490644', '0.00037136403',
#        '0.00031667072', '0.00014235002', '8.0118916e-05', '7.3917385e-05',
#        '0.00011526633', '0.00022312666', '0.0004637623', '0.00084886764',
#        '0.000706852', '0.00033865034', '0.000293465', '0.000183026',
#        '0.00014038624', '0.00021885638', '0.00020283683', '0.00041279147',
#        '0.00042428376', '0.00049497216', '0.0005390419', '0.0004843947',
#        '0.00031910176', '0.00037199084', '0.00037586404', '0.00033013336',
#        '0.00027633048', '0.00018762604', '0.00012149736', '6.003016e-05',
#        '2.9071089e-05', '1.4987378e-05', '6.0128245e-06', '1.0716038e-06',
#        '2.0672026e-07', '1.499784e-08', '7.707206e-10', '1.10959124e-10',
#        '1.1031487e-10', '1.1441411e-10', '1.1559778e-10', '1.1404174e-10',
#        '1.1101802e-10', '1.0677281e-10', '1.0168451e-10', '9.631041e-11',
#        '9.077502e-11', '8.517063e-11', '7.971514e-11', '7.445749e-11',
#        '6.94518e-11', '6.47741e-11', '6.032609e-11', '5.629021e-11',
#        '5.252213e-11', '4.905429e-11', '4.5921197e-11', '4.3054844e-11',
#        '4.046768e-11', '3.814813e-11', '3.607948e-11', '3.42442e-11',
#        '3.2629406e-11', '3.1244625e-11', '3.0058577e-11', '2.9095648e-11',
#        '2.831618e-11', '2.7754934e-11', '2.7410272e-11'], dtype='<U32')

# %%
#result_y_df = pd.DataFrame.transpose(pd.DataFrame(result_y)) #, columns = ["Var_%d" % (i + 1) for i in range(180)])

# %%
result_y_df = pd.DataFrame(result_y).transpose()

# %%
result_y_df.columns = ["Var_%d" % (i + 1) for i in range(182)]

# %%
result_y_df
# Out:
#                     Var_1 Var_2  ...        Var_181        Var_182
# 0  Ses01F_script01_1_M005     1  ...  1.5241749e-12  1.5070024e-12
#
# [1 rows x 182 columns]

# %%
random_file_name
# Out:
# 'Ses05M_impro04_F037'

# %%
random_file_name = ''

# %%
columns = ['wav_file', 'label']
ext_columns = ["Var_%d" % (i + 1) for i in range(180)]
columns.extend(ext_columns)
local_df1_features = pd.DataFrame(columns=columns)

# %%
local_df1_features
# Out:
# Empty DataFrame
# Columns: [wav_file, label, Var_1, Var_2, Var_3, Var_4, Var_5, Var_6, Var_7, Var_8, Var_9, Var_10, Var_11, Var_12, Var_13, Var_14, Var_15, Var_16, Var_17, Var_18, Var_19, Var_20, Var_21, Var_22, Var_23, Var_24, Var_25, Var_26, Var_27, Var_28, Var_29, Var_30, Var_31, Var_32, Var_33, Var_34, Var_35, Var_36, Var_37, Var_38, Var_39, Var_40, Var_41, Var_42, Var_43, Var_44, Var_45, Var_46, Var_47, Var_48, Var_49, Var_50, Var_51, Var_52, Var_53, Var_54, Var_55, Var_56, Var_57, Var_58, Var_59, Var_60, Var_61, Var_62, Var_63, Var_64, Var_65, Var_66, Var_67, Var_68, Var_69, Var_70, Var_71, Var_72, Var_73, Var_74, Var_75, Var_76, Var_77, Var_78, Var_79, Var_80, Var_81, Var_82, Var_83, Var_84, Var_85, Var_86, Var_87, Var_88, Var_89, Var_90, Var_91, Var_92, Var_93, Var_94, Var_95, Var_96, Var_97, Var_98, ...]
# Index: []
#
# [0 rows x 182 columns]

# %%
local_concat_df
# Out:
#                       0   1    ...           178           179
# 0  Ses01F_script01_1_M005   1  ...  1.524175e-12  1.507002e-12
#
# [1 rows x 182 columns]

# %%
type(columns)
# Out:
# list

# %%
wav_file_name = random_file_name
label = 1
#feature_list = np.array(wav_file_name, label)  # wav_file, label
features_list = extract_mfcc_chroma_mel(y,wav_file_name, label,mfcc=True,chroma=True,mel=True)

wav_features_df = pd.DataFrame(features_list).transpose()
wav_features_df.columns = columns
#mfcc_features_local_df = pd.DataFrame(features_local).transpose()
local_df1_features.append(wav_features_df, ignore_index=True)
#local_concat_df = pd.concat([wav_features_df,mfcc_features_local_df],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-93406650bc67> in <module>()
# ----> 1 wav_file_name = random_file_name
#       2 label = 1
#       3 #feature_list = np.array(wav_file_name, label)  # wav_file, label
#       4 features_list = extract_mfcc_chroma_mel(y,wav_file_name, label,mfcc=True,chroma=True,mel=True)
#       5
#
# NameError: name 'random_file_name' is not defined

# %%
wav_features_df
# Out:
#                       0   1    ...            180            181
# 0  Ses01F_script01_1_M005   1  ...  1.5241749e-12  1.5070024e-12
#
# [1 rows x 182 columns]

# %%
features_list
# Out:
# array(['Ses01F_script01_1_M005', '1', '-429.36743', '197.94247',
#        '-33.516186', '1.9587954', '22.986526', '-14.765762', '6.897053',
#        '3.0340722', '-17.823448', '-1.9830112', '-0.041737575',
#        '-4.8599358', '0.24192952', '-3.6559203', '-2.2123559',
#        '0.5364504', '-1.639258', '0.48715785', '-4.937517', '-6.930581',
#        '0.01405125', '-6.178031', '-8.303655', '2.384153', '2.2682624',
#        '0.6417169', '4.540103', '2.0924573', '0.6404468', '1.3444325',
#        '-1.106157', '-0.3714305', '1.5396037', '0.7600861', '0.5244653',
#        '1.0773968', '1.4269596', '0.54573524', '0.17821603', '1.3402133',
#        '0.63283706', '0.61739826', '0.61367077', '0.6365216', '0.6512044',
#        '0.6844484', '0.6593522', '0.5753417', '0.5340012', '0.5552463',
#        '0.58855873', '0.63318366', '0.019301387', '0.01995758',
#        '0.008378674', '0.020446053', '0.2581711', '0.6765364',
#        '1.3801062', '0.40456337', '0.48066786', '0.6923059', '0.7004497',
#        '0.308451', '0.3768745', '0.4173958', '0.282164', '0.5172016',
#        '0.52041197', '0.5090678', '0.42254376', '0.9727525', '0.48831218',
#        '0.38996282', '0.21696064', '0.04410654', '0.05416749',
#        '0.11983258', '0.17914502', '0.08695835', '0.13649875',
#        '0.25797203', '0.2623187', '0.25170198', '0.24210364',
#        '0.20654684', '0.1180977', '0.104577124', '0.091824874',
#        '0.1561707', '0.162776', '0.18360297', '0.22549541', '0.1246089',
#        '0.083288565', '0.106705', '0.14604391', '0.19718194',
#        '0.13716866', '0.09969044', '0.09805157', '0.07941539',
#        '0.072763726', '0.055331647', '0.039413124', '0.030656474',
#        '0.027068779', '0.021864414', '0.020950392', '0.011314254',
#        '0.0040169037', '0.0036378433', '0.0037380545', '0.004997707',
#        '0.0061653187', '0.007644438', '0.008295932', '0.011406973',
#        '0.008132427', '0.004892116', '0.0027421017', '0.002625957',
#        '0.0027963326', '0.0024215274', '0.0027976763', '0.002223857',
#        '0.002894592', '0.0028450363', '0.0027283248', '0.0021292374',
#        '0.0019809462', '0.0016094791', '0.0011447414', '0.0005020183',
#        '0.00031035635', '0.00035152797', '0.0005942152', '0.0004352172',
#        '0.0004986018', '0.00022885205', '7.466089e-05', '3.0843228e-05',
#        '3.1999458e-05', '1.1389272e-05', '2.7495428e-06', '2.7006658e-07',
#        '1.980549e-08', '8.591094e-10', '1.4214752e-11', '9.902772e-13',
#        '1.753718e-13', '1.10034716e-13', '3.8122446e-13', '7.729188e-13',
#        '1.1721069e-12', '1.534624e-12', '1.8312955e-12', '2.0551841e-12',
#        '2.2184713e-12', '2.3259983e-12', '2.3898223e-12', '2.4113495e-12',
#        '2.4050245e-12', '2.3700957e-12', '2.3229702e-12', '2.2621228e-12',
#        '2.1925842e-12', '2.1245568e-12', '2.0488097e-12', '1.973031e-12',
#        '1.9061016e-12', '1.8375434e-12', '1.768062e-12', '1.7167586e-12',
#        '1.6621281e-12', '1.6152873e-12', '1.5772751e-12', '1.5476087e-12',
#        '1.5241749e-12', '1.5070024e-12'], dtype='<U32')

# %%
local_df1_features
# Out:
# Empty DataFrame
# Columns: [wav_file, label, Var_1, Var_2, Var_3, Var_4, Var_5, Var_6, Var_7, Var_8, Var_9, Var_10, Var_11, Var_12, Var_13, Var_14, Var_15, Var_16, Var_17, Var_18, Var_19, Var_20, Var_21, Var_22, Var_23, Var_24, Var_25, Var_26, Var_27, Var_28, Var_29, Var_30, Var_31, Var_32, Var_33, Var_34, Var_35, Var_36, Var_37, Var_38, Var_39, Var_40, Var_41, Var_42, Var_43, Var_44, Var_45, Var_46, Var_47, Var_48, Var_49, Var_50, Var_51, Var_52, Var_53, Var_54, Var_55, Var_56, Var_57, Var_58, Var_59, Var_60, Var_61, Var_62, Var_63, Var_64, Var_65, Var_66, Var_67, Var_68, Var_69, Var_70, Var_71, Var_72, Var_73, Var_74, Var_75, Var_76, Var_77, Var_78, Var_79, Var_80, Var_81, Var_82, Var_83, Var_84, Var_85, Var_86, Var_87, Var_88, Var_89, Var_90, Var_91, Var_92, Var_93, Var_94, Var_95, Var_96, Var_97, Var_98, ...]
# Index: []
#
# [0 rows x 182 columns]

# %%
local_concat_df.shape
# Out:
# (1, 182)

# %%
local_df1_features.append(local_concat_df, ignore_index=True)
#local_df1_features = pd.concat([local_df1_features,local_concat_df])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-d25f8e9b8a16> in <module>()
# ----> 1 local_df1_features.append(local_concat_df, ignore_index=True)
#       2 #local_df1_features = pd.concat([local_df1_features,local_concat_df])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7749             ignore_index=ignore_index,
#    7750             verify_integrity=verify_integrity,
# -> 7751             sort=sort,
#    7752         )
#    7753
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     285     )
#     286
# --> 287     return op.get_result()
#     288
#     289
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     501
#     502             new_data = concatenate_block_managers(
# --> 503                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy,
#     504             )
#     505             if not self.copy:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      52     blocks = []
#      53
# ---> 54     for placement, join_units in concat_plan:
#      55
#      56         if len(join_units) == 1 and not join_units[0].indexers:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/concat.py in _combine_concat_plans(plans, concat_axis)
#     559         while num_ended[0] != len(next_items):
#     560             if num_ended[0] > 0:
# --> 561                 raise ValueError("Plan shapes are not aligned")
#     562
#     563             placements, units = zip(*next_items)
#
# ValueError: Plan shapes are not aligned

# %%
labels_df = pd.read_csv(labels_path)

for sess in (range(1, 6)):
        audio_vectors = pickle.load(open('{}{}.pkl'.format(audio_vectors_path, sess), 'rb'))
        for index, row in tqdm(labels_df[labels_df['wav_file'].str.contains('Ses0{}'.format(sess))].iterrows()):
            try:
                wav_file_name = row['wav_file']
                label = emotion_dict[row['emotion']]
                y = audio_vectors[wav_file_name]

                feature_list = [wav_file_name, label]  # wav_file, label
                sig_mean = np.mean(abs(y))
                feature_list.append(sig_mean)  # sig_mean
                feature_list.append(np.std(y))  # sig_std

                rmse = librosa.feature.rms(y + 0.0001)[0]
                feature_list.append(np.mean(rmse))  # rmse_mean
                feature_list.append(np.std(rmse))  # rmse_std

                silence = 0
                for e in rmse:
                    if e <= 0.4 * np.mean(rmse):
                        silence += 1
                silence /= float(len(rmse))
                feature_list.append(silence)  # silence

                y_harmonic = librosa.effects.hpss(y)[0]
                feature_list.append(np.mean(y_harmonic) * 1000)  # harmonic (scaled by 1000)

                # based on the pitch detection algorithm mentioned here:
                # http://access.feld.cvut.cz/view.php?cisloclanku=2009060001
                cl = 0.45 * sig_mean
                center_clipped = []
                for s in y:
                    if s >= cl:
                        center_clipped.append(s - cl)
                    elif s <= -cl:
                        center_clipped.append(s + cl)
                    elif np.abs(s) < cl:
                        center_clipped.append(0)
                auto_corrs = librosa.core.autocorrelate(np.array(center_clipped))
                feature_list.append(1000 * np.max(auto_corrs)/len(auto_corrs))  # auto_corr_max (scaled by 1000)
                feature_list.append(np.std(auto_corrs))  # auto_corr_std

                df_features = df_features.append(pd.DataFrame(feature_list, index=columns).transpose(), ignore_index=True)
            except:
                print('Some exception occured')

df_features.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features.csv', index=False)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-191498122aa7> in <module>()
#       6             #try:
#       7                 wav_file_name = row['wav_file']
# ----> 8                 label = emotion_dict[row['emotion']]
#       9                 y = audio_vectors[wav_file_name]
#      10
#
# NameError: name 'emotion_dict' is not defined

# %%
columns = ['wav_file', 'label']
ext_columns = ["Var_%d" % (i + 1) for i in range(180)]
columns.extend(ext_columns)
df1_features = pd.DataFrame(columns=columns)

# %%
df1_features
# Out:
# Empty DataFrame
# Columns: [wav_file, label, Var_1, Var_2, Var_3, Var_4, Var_5, Var_6, Var_7, Var_8, Var_9, Var_10, Var_11, Var_12, Var_13, Var_14, Var_15, Var_16, Var_17, Var_18, Var_19, Var_20, Var_21, Var_22, Var_23, Var_24, Var_25, Var_26, Var_27, Var_28, Var_29, Var_30, Var_31, Var_32, Var_33, Var_34, Var_35, Var_36, Var_37, Var_38, Var_39, Var_40, Var_41, Var_42, Var_43, Var_44, Var_45, Var_46, Var_47, Var_48, Var_49, Var_50, Var_51, Var_52, Var_53, Var_54, Var_55, Var_56, Var_57, Var_58, Var_59, Var_60, Var_61, Var_62, Var_63, Var_64, Var_65, Var_66, Var_67, Var_68, Var_69, Var_70, Var_71, Var_72, Var_73, Var_74, Var_75, Var_76, Var_77, Var_78, Var_79, Var_80, Var_81, Var_82, Var_83, Var_84, Var_85, Var_86, Var_87, Var_88, Var_89, Var_90, Var_91, Var_92, Var_93, Var_94, Var_95, Var_96, Var_97, Var_98, ...]
# Index: []
#
# [0 rows x 182 columns]

# %%
data_dir = '/content/drive/My Drive/IEMOCAP/pre-processed/'
labels_path = '{}df_iemocap.csv'.format(data_dir)
audio_vectors_path = '{}audio_vectors_'.format(data_dir)

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'exc': 2,
                'sad': 3,
                'fru': 4,
                'fea': 5,
                'sur': 6,
                'neu': 7,
                'xxx': 8,
                'oth': 8}

# %%
labels_df = pd.read_csv(labels_path)
columns_head = ['wav_file', 'label']
ext_columns = ["Var_%d" % (i + 1) for i in range(180)]
columns_head.extend(ext_columns)
#print(columns_head)
#first_time = True
#iter = 0
for sess in range(1,6):
        audio_vectors = pickle.load(open('{}{}.pkl'.format(audio_vectors_path, sess), 'rb'))
        #first_time = True
        #print(audio_vectors)
        #iter = 0
        for index, row in tqdm(labels_df[labels_df['wav_file'].str.contains('Ses0{}'.format(sess))].iterrows()):
            #iter = iter + 1
            #print(index,row)
            #if iter > 2:
            #  break
            try:
                wav_file_name = row['wav_file']
                label = emotion_dict[row['emotion']]
                y = audio_vectors[wav_file_name]
                #print(wav_file_name, label)

                #feature_list = [wav_file_name, label]  # wav_file, label
                features_list = extract_mfcc_chroma_mel(y,wav_file_name, label, mfcc=True,chroma=True,mel=True)
                #print(features_list)
                wav_features_df = pd.DataFrame(features_list).transpose()
                #print(wav_features_df)
                #mfcc_features_local_df = pd.DataFrame(features_local).transpose()
                #if first_time == True:
                wav_features_df.columns = columns_head
                
                #local_concat_df = pd.concat([wav_features_df,mfcc_features_local_df],axis=1)
                df1_features = df1_features.append(wav_features_df, ignore_index=True)
                #print(df1_features)
                #first_time = False
            except:
                print('Some exception occured')

df1_features.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features_mfcc_chroma_mel.csv', index=False)
# Out:
# 1346it [02:57,  8.50it/s]
# Some exception occured
# 1819it [04:04,  7.45it/s]
# 1811it [04:45,  6.35it/s]
# 1911it [05:26,  5.48it/s]
# Some exception occured
# 2136it [06:08,  5.80it/s]
# 2103it [06:51,  5.11it/s]
# 1022it [03:32,  4.90it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=0
#   n_fft, y.shape[-1]
# 1026it [03:32,  9.54it/s]
# Some exception occured
# Some exception occured
# Some exception occured
# 1068it [03:41,  8.18it/s]
# Some exception occured
# Some exception occured
# Some exception occured
# 2170it [08:00,  4.52it/s]

# %%
df1_features
# Out:
#                      wav_file label  ...        Var_179        Var_180
# 0      Ses01F_script02_1_F000     7  ...  1.9260868e-10  1.8967458e-10
# 1      Ses01F_script02_1_F001     4  ...  1.2034281e-12  1.1859532e-12
# 2      Ses01F_script02_1_F002     8  ...   1.669867e-08  1.6464817e-08
# 3      Ses01F_script02_1_F003     6  ...  4.7864496e-13  4.6700805e-13
# 4      Ses01F_script02_1_F004     7  ...  3.1830684e-12  3.1400976e-12
# ...                       ...   ...  ...            ...            ...
# 10026     Ses05F_impro01_M020     4  ...  1.3229413e-10  1.3025907e-10
# 10027     Ses05F_impro01_M021     4  ...  4.1175965e-10  4.0489853e-10
# 10028     Ses05F_impro01_M022     8  ...  1.4193737e-11  1.3989999e-11
# 10029     Ses05F_impro01_M023     4  ...  2.0887583e-13  2.0582425e-13
# 10030     Ses05F_impro01_M024     8  ...    8.74192e-13  8.6204405e-13
#
# [10031 rows x 182 columns]

# %%
### Speech files creation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from IPython.display import display

# %matplotlib inline

# %%
labels_df.head()
# Out:
#    start_time  end_time                wav_file emotion  val  act  dom
# 0       15.14   17.2100  Ses01F_script02_1_F000     neu  2.5  2.0  2.0
# 1       25.91   27.4125  Ses01F_script02_1_F001     fru  2.5  2.0  2.5
# 2       38.99   40.0500  Ses01F_script02_1_F002     xxx  2.0  2.0  2.5
# 3       45.06   47.0300  Ses01F_script02_1_F003     sur  2.5  3.0  3.0
# 4       49.22   51.4000  Ses01F_script02_1_F004     neu  2.0  3.0  3.0

# %%
df_audio_basic = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features.csv')

# %%
df_audio_basic.head()
# Out:
#                  wav_file  label  ...  auto_corr_max  auto_corr_std
# 0  Ses01F_script02_1_F000      7  ...       0.038814       0.076602
# 1  Ses01F_script02_1_F001      4  ...       0.005181       0.008782
# 2  Ses01F_script02_1_F002      8  ...       2.428307       3.673292
# 3  Ses01F_script02_1_F003      6  ...       0.182314       0.310989
# 4  Ses01F_script02_1_F004      7  ...       0.149445       0.354042
#
# [5 rows x 10 columns]

# %%
df_audio_mfcc = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features_mfcc_chroma_mel.csv')

# %%
df_audio_mfcc.head()
# Out:
#                  wav_file  label  ...       Var_179       Var_180
# 0  Ses01F_script02_1_F000      7  ...  1.926087e-10  1.896746e-10
# 1  Ses01F_script02_1_F001      4  ...  1.203428e-12  1.185953e-12
# 2  Ses01F_script02_1_F002      8  ...  1.669867e-08  1.646482e-08
# 3  Ses01F_script02_1_F003      6  ...  4.786450e-13  4.670081e-13
# 4  Ses01F_script02_1_F004      7  ...  3.183068e-12  3.140098e-12
#
# [5 rows x 182 columns]

# %%
df_audio_complete = pd.merge(df_audio_basic, df_audio_mfcc, on=['wav_file','label'])

# %%
df_audio_complete.head()
# Out:
#                  wav_file  label  ...       Var_179       Var_180
# 0  Ses01F_script02_1_F000      7  ...  1.926087e-10  1.896746e-10
# 1  Ses01F_script02_1_F001      4  ...  1.203428e-12  1.185953e-12
# 2  Ses01F_script02_1_F002      8  ...  1.669867e-08  1.646482e-08
# 3  Ses01F_script02_1_F003      6  ...  4.786450e-13  4.670081e-13
# 4  Ses01F_script02_1_F004      7  ...  3.183068e-12  3.140098e-12
#
# [5 rows x 190 columns]

# %%
df_audio_complete.shape
# Out:
# (10031, 190)

# %%
df_audio_complete.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features_complete.csv')

# %%
df_audio_complete[df_audio_complete['wav_file'].str.contains('Ses01')]
# Out:
#                     wav_file  label  ...       Var_179       Var_180
# 0     Ses01F_script02_1_F000      7  ...  1.926087e-10  1.896746e-10
# 1     Ses01F_script02_1_F001      4  ...  1.203428e-12  1.185953e-12
# 2     Ses01F_script02_1_F002      8  ...  1.669867e-08  1.646482e-08
# 3     Ses01F_script02_1_F003      6  ...  4.786450e-13  4.670081e-13
# 4     Ses01F_script02_1_F004      7  ...  3.183068e-12  3.140098e-12
# ...                      ...    ...  ...           ...           ...
# 1813  Ses01M_script01_3_M039      3  ...  2.569193e-13  2.533515e-13
# 1814  Ses01M_script01_3_M040      3  ...  4.158911e-13  4.095847e-13
# 1815  Ses01M_script01_3_M041      3  ...  4.322679e-12  4.258656e-12
# 1816  Ses01M_script01_3_M042      8  ...  8.660666e-13  8.537900e-13
# 1817  Ses01M_script01_3_M043      1  ...  1.094077e-13  1.063524e-13
#
# [1818 rows x 190 columns]

# %%
df = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features.csv')
df = df[df['label'].isin([0, 1, 2, 3, 4, 5, 6, 7])]
print(df.shape)
display(df.head())

# change 7 to 2
df['label'] = df['label'].map({0: 0, 1: 1, 2: 1, 3: 2, 4: 2, 5: 3, 6: 4, 7: 5})
df.head()
# Out:
# (7523, 10)
#                  wav_file  label  ...  auto_corr_max  auto_corr_std
# 0  Ses01F_script02_1_F000      7  ...       0.038814       0.076602
# 1  Ses01F_script02_1_F001      4  ...       0.005181       0.008782
# 3  Ses01F_script02_1_F003      6  ...       0.182314       0.310989
# 4  Ses01F_script02_1_F004      7  ...       0.149445       0.354042
# 6  Ses01F_script02_1_F006      0  ...       0.667884       1.667755
#
# [5 rows x 10 columns]
#                  wav_file  label  ...  auto_corr_max  auto_corr_std
# 0  Ses01F_script02_1_F000      5  ...       0.038814       0.076602
# 1  Ses01F_script02_1_F001      2  ...       0.005181       0.008782
# 3  Ses01F_script02_1_F003      4  ...       0.182314       0.310989
# 4  Ses01F_script02_1_F004      5  ...       0.149445       0.354042
# 6  Ses01F_script02_1_F006      0  ...       0.667884       1.667755
#
# [5 rows x 10 columns]

# %%
df.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/no_sample_df.csv')

# oversample fear
fear_df = df[df['label']==3]
for i in range(30):
    df = df.append(fear_df)

sur_df = df[df['label']==4]
for i in range(10):
    df = df.append(sur_df)
    
df.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/modified_df.csv')

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'sad': 2,
                'neu': 3,}

# emotion_dict = {'ang': 0,
#                 'hap': 1,
#                 'exc': 2,
#                 'sad': 3,
#                 'fru': 4,
#                 'fea': 5,
#                 'sur': 6,
#                 'neu': 7,
#                 'xxx': 8,
#                 'oth': 8}

scalar = MinMaxScaler()
df[df.columns[2:]] = scalar.fit_transform(df[df.columns[2:]])
df.head()
# Out:
#                  wav_file  label  ...  auto_corr_max  auto_corr_std
# 0  Ses01F_script02_1_F000      5  ...       0.000466       0.000268
# 1  Ses01F_script02_1_F001      2  ...       0.000059       0.000029
# 3  Ses01F_script02_1_F003      4  ...       0.002202       0.001097
# 4  Ses01F_script02_1_F004      5  ...       0.001805       0.001249
# 6  Ses01F_script02_1_F006      0  ...       0.008078       0.005893
#
# [5 rows x 10 columns]

# %%
x_train, x_test = train_test_split(df, test_size=0.20)

x_train.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_train.csv', index=False)
x_test.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_test.csv', index=False)

print(x_train.shape, x_test.shape)
# Out:
# (6018, 10) (1505, 10)

# %%
#### MFCC features

# %%
df_mfcc = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_features_mfcc_chroma_mel.csv')

# %%
columns_head = ['wav_file', 'label']
ext_columns = ["Var_%d" % (i + 1) for i in range(180)]
columns_head.extend(ext_columns)

# %%
df_mfcc.head(-5)
# Out:
#                      wav_file  label  ...       Var_179       Var_180
# 0      Ses01F_script02_1_F000      7  ...  1.926087e-10  1.896746e-10
# 1      Ses01F_script02_1_F001      4  ...  1.203428e-12  1.185953e-12
# 2      Ses01F_script02_1_F002      8  ...  1.669867e-08  1.646482e-08
# 3      Ses01F_script02_1_F003      6  ...  4.786450e-13  4.670081e-13
# 4      Ses01F_script02_1_F004      7  ...  3.183068e-12  3.140098e-12
# ...                       ...    ...  ...           ...           ...
# 10021     Ses05F_impro01_M015      4  ...  4.955613e-10  4.877030e-10
# 10022     Ses05F_impro01_M016      8  ...  4.902614e-13  4.826832e-13
# 10023     Ses05F_impro01_M017      4  ...  1.675483e-12  1.650818e-12
# 10024     Ses05F_impro01_M018      4  ...  1.090755e-09  1.074881e-09
# 10025     Ses05F_impro01_M019      4  ...  4.939889e-10  4.864139e-10
#
# [10026 rows x 182 columns]

# %%
df_mfcc.columns = columns_head
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7be290fb50fb> in <module>()
# ----> 1 df_mfcc.columns = columns_head
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     225         if new_len != old_len:
#     226             raise ValueError(
# --> 227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#     229             )
#
# ValueError: Length mismatch: Expected axis has 364 elements, new values have 182 elements

# %%
df_mfcc = df_mfcc[df_mfcc['label'].isin([0, 1, 2, 3, 4, 5, 6, 7])]
print(df_mfcc.shape)
display(df_mfcc.head())

# change 7 to 2
df_mfcc['label'] = df_mfcc['label'].map({0: 0, 1: 1, 2: 1, 3: 2, 4: 2, 5: 3, 6: 4, 7: 5})
df_mfcc.head()
# Out:
# (7523, 182)
#                  wav_file  label  ...       Var_179       Var_180
# 0  Ses01F_script02_1_F000      7  ...  1.926087e-10  1.896746e-10
# 1  Ses01F_script02_1_F001      4  ...  1.203428e-12  1.185953e-12
# 3  Ses01F_script02_1_F003      6  ...  4.786450e-13  4.670081e-13
# 4  Ses01F_script02_1_F004      7  ...  3.183068e-12  3.140098e-12
# 6  Ses01F_script02_1_F006      0  ...  1.122146e-09  1.106341e-09
#
# [5 rows x 182 columns]
#                  wav_file  label  ...       Var_179       Var_180
# 0  Ses01F_script02_1_F000      5  ...  1.926087e-10  1.896746e-10
# 1  Ses01F_script02_1_F001      2  ...  1.203428e-12  1.185953e-12
# 3  Ses01F_script02_1_F003      4  ...  4.786450e-13  4.670081e-13
# 4  Ses01F_script02_1_F004      5  ...  3.183068e-12  3.140098e-12
# 6  Ses01F_script02_1_F006      0  ...  1.122146e-09  1.106341e-09
#
# [5 rows x 182 columns]

# %%
emotion_dict_new = {'ang': 0,
                'hap': 1,
                'sad': 2,
                'neu': 3,}

# emotion_dict = {'ang': 0,
#                 'hap': 1,
#                 'exc': 2,
#                 'sad': 3,
#                 'fru': 4,
#                 'fea': 5,
#                 'sur': 6,
#                 'neu': 7,
#                 'xxx': 8,
#                 'oth': 8}

scalar = StandardScaler()
df_mfcc[df_mfcc.columns[2:]] = scalar.fit_transform(df_mfcc[df_mfcc.columns[2:]])
df_mfcc.head()
# Out:
#                  wav_file  label     Var_1  ...   Var_178   Var_179   Var_180
# 0  Ses01F_script02_1_F000      5  0.026255  ... -0.030140 -0.030161 -0.030174
# 1  Ses01F_script02_1_F001      2 -0.822233  ... -0.035826 -0.035844 -0.035855
# 3  Ses01F_script02_1_F003      4  0.600334  ... -0.035848 -0.035866 -0.035877
# 4  Ses01F_script02_1_F004      5  0.351823  ... -0.035768 -0.035785 -0.035796
# 6  Ses01F_script02_1_F006      0  1.117108  ... -0.002586 -0.002560 -0.002545
#
# [5 rows x 182 columns]

# %%
x_train_mfcc, x_test_mfcc = train_test_split(df_mfcc, test_size=0.20)

x_train_mfcc.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_train_mfcc.csv', index=False)
x_test_mfcc.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_test_mfcc.csv', index=False)

print(x_train_mfcc.shape, x_test_mfcc.shape)
# Out:
# (6018, 182) (1505, 182)

# %%
### Process text

# %%
import unicodedata

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
import re
import os
import pickle

useful_regex = re.compile(r'^(\w+)', re.IGNORECASE)

file2transcriptions = {}

for sess in range(1, 6):
    transcripts_path = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session{}/dialog/transcriptions/'.format(sess)
    transcript_files = os.listdir(transcripts_path)
    for f in transcript_files:
        with open('{}{}'.format(transcripts_path, f), 'r') as f:
            all_lines = f.readlines()

        for l in all_lines:
            audio_code = useful_regex.match(l).group()
            transcription = l.split(':')[-1].strip()
            # assuming that all the keys would be unique and hence no `try`
            file2transcriptions[audio_code] = transcription
# save dict
with open('/content/drive/My Drive/IEMOCAP/pre-processed/audiocode2text.pkl', 'wb') as file:
    pickle.dump(file2transcriptions, file)
len(file2transcriptions)
# Out:
# 10087

# %%
audiocode2text = pickle.load(open('/content/drive/My Drive/IEMOCAP/pre-processed/audiocode2text.pkl', 'rb'))

# %%
audiocode2text
# Out:
# {'Ses01M_impro07_M000': "Check this out.  You know how I've told you I've been really into like softball recently?",
#  'Ses01M_impro07_F000': 'Yeah.',
#  'Ses01M_impro07_M001': 'Well, this is totally random, I got this full ride scholarship to go to U.S.C next year to play softball.',
#  'Ses01M_impro07_F001': "[LAUGHTER]. For softball? That's unbelievable. Is it slow pitch?",
#  'Ses01M_impro07_M002': "For softball.  They're going to pay me to go to school. Isn't that awesome?",
#  'Ses01M_impro07_M003': "Yeah.  Well, I don't--well yeah I can pitch, I'm not like the pitcher though. I'm like the pinch hitter guy I mostly just hit.  But I guess I'm going to have to... Yeah, and then I play shortstop too but... It's so ex- The good news is I get to stay here.",
#  'Ses01M_impro07_F002': 'Uh huh.',
#  'Ses01M_impro07_F003': 'Pinch hitting softball.',
#  'Ses01M_impro07_F004': 'That is incredible.',
#  'Ses01M_impro07_F005': "That's amazing. They pay for everything?",
#  'Ses01M_impro07_M004': 'I know. For softball, yeah.',
#  'Ses01M_impro07_F006': 'Your housing, books, everything? That is incredible.',
#  'Ses01M_impro07_M005': "Yeah, everything. Every like- free ride and I get to, you know, like be on like a Trojans sports team too. And it's like cool. Isn't it awesome?",
#  'Ses01M_impro07_F007': 'That is incredible. Do you get like a per diem?',
#  'Ses01M_impro07_M006': "I don't know. I should ask. Yeah, I will.",
#  'Ses01M_impro07_F008': 'You should...You should look into that.',
#  'Ses01M_impro07_F009': 'That is amazing, congratulations. Good for you.',
#  'Ses01M_impro07_M007': 'Thank you.',
#  'Ses01M_impro07_M008': "But I don't know I want to live in the housing that they give me though 'cause I think I want to you know like get like a nicer place.",
#  'Ses01M_impro07_F010': 'Oh.',
#  'Ses01M_impro07_F011': 'Yeah, that you probably. You should see one of these Victorian houses around by.',
#  'Ses01M_impro07_M009': 'Where should I move?',
#  'Ses01M_impro07_M010': "That's a really good idea. Or I could go to like Santa Monica. Go beach. Venice beach, yeah a little dirty though. I don't want to go to Venice beach. But - Malibu. All right.",
#  'Ses01M_impro07_F012': 'Oh. Venice beach.',
#  'F': 'Oh dear',
#  'Ses01M_impro07_F013': "Oh, you don't like that. You're west-sider?",
#  'Ses01M_impro07_F014': "Okay. That would be way too much of a commute you can't do that. Especially- I know especially from--I don't know, what I was going to say, I don't know.",
#  'Ses01M_impro07_M011': 'Professional softball player Malibu. [LAUGHTER]',
#  'Ses01M_impro07_M012': "From where? Huh? Well I'm from San Francisco.",
#  'Ses01M_impro07_F015': "I don't know. Commuting from what Malibu that would be ridiculous.",
#  'Ses01M_impro07_M013': 'Oh yeah, that would be.  Well, depends on what type of car you had, though too. I guess it would be worth it. helicopter. Yeah, helicopter.  There is a helipad there, right? Yeah, exactly.',
#  'Ses01M_impro07_F016': "Oh yeah. He'd drop you right off at practice?",
#  'Ses01M_impro07_F017': "Do you--are you one of those like four a clock in the morning practices?  Is it--that's more like swimming and- --ballet and things like that.",
#  'Ses01M_impro07_M014': "Yeah. I think it's in the afternoon 'cause I mean can't be too early 'cause then you can't see the ball.",
#  'Ses01M_impro07_F018': "They have those neon--softballs.  They're like day-glow you can see them anywhere.",
#  'Ses01M_impro07_M015': "Yeah, but no. Well, they have a night games but you know there's more like night games they're not like morning games, you know. I guess it's kind of same thing.",
#  'Ses01M_impro07_F019': "I'm surprised you don't know that.",
#  'Ses01M_impro07_F020': 'Oh. That is incredible. Is it--',
#  'Ses01M_impro07_F021': "do they have a--is it a co-ed softball team?  I mean... Really? You know, I didn't even know that they have that.",
#  'Ses01M_impro07_M016': "No it's all boys. All boys' softball team.",
#  'Ses01M_impro07_M017': "They do it's--believe me it's huge.",
#  'Ses01M_impro07_F022': 'Who do you play? Like do--are you like... nationally ranked?',
#  'Ses01M_impro07_M018': 'I just got into it. I just kind of fell into it. Literally I was walking around and...',
#  'Ses01M_impro07_F023': 'That is unbelievable.',
#  'Ses01M_impro07_M019': "It's pretty wild.",
#  'Ses01M_impro07_F024': 'I would put that right up there with--ping-pong.',
#  'Ses01M_impro07_M020': 'Yeah, well I doubt [GARBAGE] ping pong [GARBAGE]',
#  'Ses01M_impro07_F025': "I mean not to denigrate what you are doing.  I think that's great.",
#  'Ses01M_impro07_M021': "Oh you mean it's not really sport that what you're saying?",
#  'Ses01M_impro07_F026': 'No, no.  I love softball. I played softball all the time.',
#  'Ses01M_impro07_M022': "It's totally a sport. What are you talking about?",
#  'Ses01M_impro07_M023': "What, just 'cause I don't play regular baseball doesn't mean I'm like any less of like a sports guy.",
#  'Ses01M_impro07_F027': "I am not saying you should be. I'm not no. I think it's great I think you should be incredibly proud yourself especially because you're going to U.S.C for free for doing it. For free.",
#  'Ses01M_impro07_M024': "For free that's really what it's about. I mean who cares I mean if I have to play softball all the time?",
#  'Ses01M_impro07_M025': 'But they got to like drive around in a bus--that would suck.',
#  'Ses01M_impro07_F028': 'Oh really? With the whole team?',
#  'Ses01M_impro07_M026': 'Yeah we have like away games and stuff.',
#  'Ses01M_impro07_F029': "What are your teammates like? I'm sure you don't know yet? What kind of people play softball?",
#  'Ses01M_impro07_M027': "They're nice.",
#  'Ses01M_impro07_M028': "Like, you know like police officers, like--kind of heavyset guys. Mustaches, yeah. It's that kind of-",
#  'Ses01M_impro07_F030': 'Oh really?',
#  'Ses01M_impro07_F031': "Cool. You don't seem like you'd fit in there.",
#  'Ses01M_impro07_M029': "That kind of...They're okay.  No I'm like- I'm kind of like the odd man out I'm like...",
#  'Ses01M_impro07_F032': 'Oh, cool.',
#  'Ses01M_impro07_M030': "But you know I'm like [GARBAGE].",
#  'Ses01M_impro07_F033': "You're like the rookie? The new kid.",
#  'Ses01M_impro07_M031': 'Yeah.',
#  'Ses01M_impro07_F034': "Just watch in five years you'll be like on the force. You carry around donuts in your back pocket... [LAUGHTER]",
#  'Ses01M_impro07_M032': "I'm going to have a mustache...On the force...",
#  'Ses01M_impro07_M033': 'Pull over..',
#  'Ses01F_script01_2_F000': 'Why did he invite her here?',
#  'Ses01F_script01_2_M000': 'Why does that bother you?',
#  'Ses01F_script01_2_F001': "She's been in New York three and an half years, why all of a sudden?",
#  'Ses01F_script01_2_M001': 'Well maybe...maybe he just wanted to see her.',
#  'Ses01F_script01_2_F002': 'Nobody comes seven hundred miles just to see.',
#  'Ses01F_script01_2_M002': "What do you mean?  You know he lived next door to the girl his whole life, why wouldn't he want to see her?",
#  'Ses01F_script01_2_M003': "[BREATHING] You don't look at me like that.  He didn't tell me anything more than he told you.",
#  'Ses01F_script01_2_F003': "He's not going to marry her.",
#  'Ses01F_script01_2_M004': "How do you know he's even thinking about it?",
#  'Ses01F_script01_2_F004': "It's got that about it.",
#  'Ses01F_script01_2_M005': 'Oh.  So what.',
#  'Ses01F_script01_2_F005': 'What is going on here, Joe?',
#  'Ses01F_script01_2_M006': 'Now listen.',
#  'Ses01F_script01_2_F006': "She is not his girl.  She knows she's not.",
#  'Ses01F_script01_2_M007': "You can't read her mind.",
#  'Ses01F_script01_2_F007': "Then why is she still single?  New York is full of men, why is she still single?  Probably a hundred people told her she's foolish, but she waited.",
#  'Ses01F_script01_2_M008': 'How do you know why she waited?',
#  'Ses01F_script01_2_F008': "Because she knows what I know, that's why.  She's faithful as a rock.  In my darkest moments, I think of her waiting and I know that I'm right.",
#  'Ses01F_script01_2_M009': "Hey look, it's a nice day, huh?  Why are we arguing?",
#  'Ses01F_script01_2_F009': 'Nobody in this house dares take away her faith, Joe.  You know strangers might, but not his father, not his brother.',
#  'Ses01F_script01_2_M010': 'What do you want me to do? What do you want?',
#  'Ses01F_script01_2_F010': "I want you to-- I want you to act like he is coming back, both of you.  Don't think I haven't noticed you since Chris invited her here.",
#  'Ses01F_script01_2_F011': "I won't stand for any nonsense.",
#  'Ses01F_script01_2_M011': 'Kate.',
#  'Ses01F_script01_2_F012': "Because if he's not coming back, I'll kill myself.  Oh laugh, laugh all you like but why does this happen the very night he comes back.  She goes to sleep in his room and his memorial breaks in pieces.  Look at it, Joe, look.",
#  'Ses01F_script01_2_M012': '[BREATHING]',
#  'Ses01F_script01_2_M013': 'Calm yourself.',
#  'Ses01F_script01_2_F013': 'Just believe with me, Joe. Only last week a man came back in Detroit missing longer than Larry.  Believe with me. You, above all, have got to believe. Just believe.',
#  'Ses01F_script01_2_M014': 'Okay. Calm yourself.',
#  'Ses01F_script01_2_M015': 'I know. All right, all right. All right. Okay.  Calm yourself. What does that mean, me above all?',
#  'Ses01F_script01_2_M016': "Look at you, you're shaking.",
#  'Ses01F_script01_2_F014': "I can't help it.",
#  'Ses01F_script01_2_M017': 'What have I got to hide?  What the hell is the matter with you, Kate?',
#  'Ses01M_script02_1_M000': "What time is it?  God, this is great, isn't it?  I can't believe it.",
#  'Ses01M_script02_1_M001': "Of course I did want to a little further up the coast you know get away from all the lights and people and everything.  Is it midnight, do they always start at midnight?  Is that what it is midnight?  How you doing, huh? You okay?  That's good.",
#  'Ses01M_script02_1_F000': "I'm fine.",
#  'Ses01M_script02_1_M002': "Look, there what's that, what's that?  Is it--",
#  'Ses01M_script02_1_M003': "No, I think that's just foam.",
#  'Ses01M_script02_1_F001': 'Ugh...',
#  'Ses01M_script02_1_M004': "Oh, no I can't tell though.  Although probably if you can't tell it probably isn't them right, yeah.  Probably going to be like unmistakable, right?",
#  'Ses01M_script02_1_M005': "Gosh, this is great, isn't it?  This is awesome.  Oh, no you know what I forgot?",
#  'Ses01M_script02_1_M006': 'My flashlight.  How could I forget my flashlight?  God--',
#  'Ses01M_script02_1_F002': 'What flashlight?',
#  'Ses01M_script02_1_M007': "Flashlight the silver one.  There's only one isn't there?",
#  'Ses01M_script02_1_F003': "That's not your flashlight.",
#  'Ses01M_script02_1_M008': 'Whose is it?',
#  'Ses01M_script02_1_F004': "It's ours; it's my flashlight, too.",
#  'Ses01M_script02_1_M009': 'Oh, well, yeah of course.',
#  'Ses01M_script02_1_F005': 'You keep saying "my flashlight" like somehow it\'s just yours. How\'s that supposed to make me feel?',
#  'M': 'Oh [garbage]',
#  'Ses01M_script02_1_M010': "Of course, our flashlight.  What's your is mine, mi flashlight es su flashlight.",
#  'Ses01M_script02_1_M011': "Gosh, I should have brought it. I can't believe I forgot that.",
#  'Ses01M_script02_1_M012': "It's a nice moon though, should stay full.  Do they always run during a full moon?  I can't remember was it full last year?",
#  'Ses01M_script02_1_F006': 'Yeah.',
#  'Ses01M_script02_1_M013': 'Are you all right?  Are you okay?  You cold?  Do you want to my jacket? My jacket? No?',
#  'Ses01M_script02_1_F007': 'No.',
#  'Ses01M_script02_1_M014': "You know what we should've brought a blanket too.  Man, our blanket, our blanket.  Wish I had six-pack too, a six-pack would be just the ticket right about now, huh, six-pack.",
#  'Ses01M_script02_1_M015': "What's wrong?  Are you okay?  Huh?  You cold?",
#  'Ses01M_script02_1_F008': "I'm fine.",
#  'Ses01M_script02_1_M016': "Oh yeah, I'm so excited right now I'm like a kid.",
#  'Ses01M_script02_1_M017': "I can't believe I got out of the house without my fly zipped up even.",
#  'Ses01M_script02_1_F009': 'I wonder if they can hear me talk',
#  'Ses01M_script02_1_M018': 'I wonder if they can hear me talking, you know.',
#  'Ses01M_script02_1_M019': 'Like feel the vibrations in the sand when we move around.',
#  'Ses01M_script02_1_F010': "I'm cold.",
#  'Ses01M_script02_1_M020': 'Do you want my jacket?',
#  'Ses01M_script02_1_F011': "It's after eleven, let's go home.",
#  'Ses01M_script02_1_M021': "What are you kidding?  We just got here.  We don't want to turn around and go home now.  What's the point coming all the way down here?",
#  'Ses01M_script02_1_F012': 'There is no point.',
#  'Ses01M_script02_1_M022': 'Right.',
#  'Ses01M_script02_1_F013': "That's my point.",
#  'Ses01M_script02_1_M023': "That's my point too.",
#  'Ses01M_script02_1_F014': "Then let's go.",
#  'Ses01M_script02_1_M024': "No, wait no, no that's not my point.  My point is there is no point and coming all the way down here if we just turn around and go home.",
#  'Ses01M_script02_1_M025': "Don't you want to see it?",
#  'Ses01M_script02_1_F015': 'Not particularly.',
#  'Ses01M_script02_1_M026': 'Why not?',
#  'Ses01M_script02_1_F016': "I just don't, it's stupid.",
#  'Ses01M_script02_1_M027': "It's not stupid.  It's a natural phenomenon.",
#  'Ses01M_script02_1_M028': "People in Kansas would have to get plane tickets and make hotel reservations to see this.  It's only forty minutes away; it's just too good to pass up.",
#  'Ses01M_script02_1_F017': 'Pass what up?  These little fish swim out of the ocean, they flop around on the sand then they swim back and then they die.',
#  'Ses01M_script02_1_M029': "Yeah but that like flopping around is what to do it's like spawning or mating or something.  This is like the highlight of their little fish lives.  It's like life's last orgy.",
#  'Ses01M_script02_1_F018': "I don't know what you're so excited about.  This isn't a moon landing we're talking about, it's fish, it's a fish nobody even eats.",
#  'Ses01M_script02_1_M030': 'Yeah, they do.',
#  'Ses01M_script02_1_F019': 'Oh, Augie.',
#  'Ses01M_script02_1_M031': "Well, okay whatever, okay but it's a fish who do something that like no other fish do, you know, it's like those swallows that return to Capistrano or those like those lemmings that jumped off the cliffs, you know.",
#  'Ses01M_script02_1_M032': "It's like a little bit of the unexplainable, a little magic, a little mystery.  I just don't see how you can not be interested in this.",
#  'Ses01M_script02_1_F020': "I'm not.",
#  'Ses01M_script02_1_M033': 'For real?',
#  'Ses01M_script02_1_F021': 'Yes.',
#  'Ses01M_script02_1_M034': 'All right.',
#  'Ses01M_script02_1_M035': "I don't get it though, I mean the first time we came here you said it was like the best night of your life...",
#  'Ses01M_script02_1_M036': "And last year I remember like distinctively you were so excited to get here that you didn't realize you stubbed your toe until we were in a car.",
#  'Ses01M_script02_1_F022': "Last year, you'll also remember we got--our shoes got wet, I got sand in my panties, you got a sore throat, we got into a big fight and we did not see the grunions.",
#  'Ses01M_script02_1_M037': "We just weren't in a good spot though.",
#  'Ses01M_script02_1_F023': "We didn't see them the year before either.",
#  'Ses01M_script02_1_M038': "We just weren't in a good spot I'm telling you this is a much better spot.",
#  'Ses01M_script02_1_M039': "Come on, trust me I got instincts for these things, okay?  So just--just think about it all right?  Okay, I know you're not interested, think about it...",
#  'Ses01M_script02_1_M040': "Out there, there's like this big mass of silver fish they're heading this way...",
#  'Ses01M_script02_1_M041': "They don't know why, we don't know why.  No one like sent them an invitation or gave them a map or direction...",
#  'Ses01M_script02_1_M042': 'They just all turned at once and they just form this line as long as the California coast.  And they just started swimming...',
#  'Ses01M_script02_1_M043': 'Like some little time release fire cracker went off inside their little tiny bodies.  And they all turned as one...',
#  'Ses01M_script02_1_M044': 'And form the line and started swimming, swimming that would bring them to this point here...',
#  'Ses01M_script02_1_M045': "It's like urgency that's pure urge you know.  It's single-mindedness with no mind.",
#  'Ses01M_script02_1_M046': "It's crazy.  Look at this, I'm giving myself goose bumps, the hairs are standing up on my arm.",
#  'Ses01M_script02_1_F024': "That's the wind.",
#  'Ses01F_impro05_F000': 'Hi.',
#  'Ses01F_impro05_M000': 'Hi.  Thanks for waiting.',
#  'Ses01F_impro05_F001': 'Yeah. This is the fourth line that I have been in.',
#  'Ses01F_impro05_M001': 'Can I help you?',
#  'Ses01F_impro05_M002': 'Uh huh.',
#  'Ses01F_impro05_F002': 'I need my bag.',
#  'Ses01F_impro05_M003': 'Okay.',
#  'Ses01F_impro05_F003': "I flew in over three hours ago, I've been in four different lines.",
#  'Ses01F_impro05_M004': 'Okay.',
#  'Ses01F_impro05_F004': "I waited the entire baggage- I waited for the whole baggage carousel four times.  They told me to go to the next one.  I waited through that for three planes and now I'm here.",
#  'Ses01F_impro05_M005': "Okay.  Great.  I'm really sorry that you had to do that.  What's your last name?  Let's start there.",
#  'Ses01F_impro05_F005': 'Nash.',
#  'Ses01F_impro05_M006': 'Okay.',
#  'Ses01F_impro05_F006': 'No G.',
#  'Ses01F_impro05_M007': 'all right- okay.  And you lost your bag? Is that- that the issue?',
#  'Ses01F_impro05_F007': 'Yes.',
#  'Ses01F_impro05_F008': 'Flight seven fourteen.',
#  'Ses01F_impro05_M008': 'Uh-huh.',
#  'Ses01F_impro05_F009': 'Am I going to be getting, like, free tickets, free mileage. When can I expect my bag here?',
#  'Ses01F_impro05_M009': "Yeah. Yeah, I don't see- I don't see any--",
#  'Ses01F_impro05_M010': "I don't see any record of it, and I-usually when I don't see a record of it, that means um-",
#  'Ses01F_impro05_M011': "we've mistakenly lost your baggage.  We're very sorry.  On behalf of Jet Blue I would like to apologize for any inconvenience.  I am allowed to issue you a fifty dollar gift card which you can use any future flights you want to take with us.  I'm very sorry, once again...",
#  'Ses01F_impro05_F010': 'Oh, Are you kidding me?',
#  'Ses01F_impro05_M012': 'for such an inconvenience and your bag, but',
#  'Ses01F_impro05_F011': 'Is this a joke?',
#  'Ses01F_impro05_M013': 'Yeah.',
#  'Ses01F_impro05_M014': 'No, no.',
#  'Ses01F_impro05_F012': "Are there candid cameras?  Is this that movie? There's that show, right?  Airplane, airline.",
#  'Ses01F_impro05_M015': 'No, no.  This is real.',
#  'Ses01F_impro05_F013': "So you'll give me money and then I'll get my bag?",
#  'Ses01F_impro05_M016': "No.  I'm just giving you money, the bag is gone.  If it's not here, I'm really sorry there is nothing I can do because...",
#  'Ses01F_impro05_M017': "this is the only track record that we have and if it's not listed here then it's probably not anywhere.",
#  'Ses01F_impro05_F014': "You're kidding me, this is a joke.",
#  'Ses01F_impro05_M018': "Once again, I'm really- I'm really sorry.",
#  'Ses01F_impro05_F015': "Do you have any idea-- fifty dollars?  That's supposed to replace everything that I have?  Do you understand how much I have packed in there? Not only does it have sentimental value; it can't be replaced like that.  It was incredibly expensive.",
#  'Ses01F_impro05_M019': 'Yes.',
#  'Ses01F_impro05_M020': 'I know.',
#  'Ses01F_impro05_F016': "We flew in from Paris.  I've been shopping for three weeks.",
#  'Ses01F_impro05_M021': "I'm very sorry.  But if you see the sign that's right behind me here, it spells it out really clearly that we are not held liable--",
#  'Ses01F_impro05_F017': "I don't care what you're freaking sign says.  Somebody- Somebody needs to replace everything I've got there and give me money for my inconvenience.",
#  'Ses01F_impro05_M022': 'Okay. Calm-',
#  'Ses01F_impro05_M023': "Actually, we are not necessarily liable to give you- to even give you this fifty dollars so... it's actually- it's actually really",
#  'Ses01F_impro05_F018': 'Do you understand who my husband is?',
#  'Ses01F_impro05_F019': "If you're- if you're- if you're looking for a lawsuit, baby, you've found it.",
#  'Ses01F_impro05_M024': "We are actually not even allowed--  you know, like we don't have to give you this fifty dollars.  We don't have to do that.",
#  'Ses01F_impro05_F020': "Oh-Oh.  It's a gift.  You're-You're helping me out here?",
#  'Ses01F_impro05_M025': "It's a gift.",
#  'Ses01F_impro05_M026': 'You know, the airlines can not be held responsible for every bag of luggage that comes through here.',
#  'Ses01F_impro05_F021': 'You are cruising for a bruising.  You are in so much trouble.',
#  'Ses01F_impro05_M027': 'With the amount of--',
#  'Ses01F_impro05_F022': "Who's in charge?  Who is the president of Jet Blue?",
#  'Ses01F_impro05_M028': "Um, actually, I don't know. I don't know. Oh really?",
#  'Ses01F_impro05_F023': 'Because I probably know him.',
#  'Ses01F_impro05_F024': 'Yeah.',
#  'Ses01F_impro05_M029': 'Well then maybe you can just call him and he can give you more money.  But right now all I can do--',
#  'Ses01F_impro05_F025': "I don't want money, I want my clothes.",
#  'Ses01F_impro05_M030': "Right now all I can do is just give you this fifty dollars, I'm really sorry.",
#  'Ses01F_impro05_F026': "What's your name?",
#  'Ses01F_impro05_M031': 'Oh.  My name is Sean. Hi.',
#  'Ses01F_impro05_F027': 'Sean.  Great. Do you have a badge number or something?',
#  'Ses01F_impro05_M032': 'Badge number?  Uh, no.  You can just take my employee number I guess.',
#  'Ses01F_impro05_F028': "Okay.  I'll do that.",
#  'Ses01F_impro05_M033': 'Why?  Have I done something wrong?  Have I given you bad service?  I feel like I have done the best I could.',
#  'Ses01F_impro05_F029': "I don't think you have done everything you could do because I don't have my bag here yet.",
#  'Ses01F_impro05_M034': 'If you want, you can write a letter.  I can give you the address. Yes.  An angry--',
#  'Ses01F_impro05_F030': "A letter? I'll make a personal phone call.",
#  'Ses01F_impro05_M035': 'Or you can make a phone call.  But I think a letter might be a little more-- in my impression, letters have more...',
#  'Ses01F_script02_1_M000': "What time is it?  I think it's supposed to run around midnight, right?  God, this is great, isn't it, Carla?  Look at this night we got here, huh.",
#  'Ses01F_script02_1_M001': 'Actually I want to get a little further up the coast, get away from all like the lights and the people, but...  How are you doing?',
#  'Ses01F_script02_1_F000': 'Fine.',
#  'Ses01F_script02_1_M002': 'Okay.  Is that, is that--',
#  'Ses01F_script02_1_M003': "No.  That's just foam.  I don't know.  I can't tell.",
#  'Ses01F_script02_1_F001': '[BREATHING]',
#  'Ses01F_script02_1_M004': "I don't know, probably if you can't tell, though, it's probably not them, right?  It's probably going to be like this unmistakable thing, right?",
#  'Ses01F_script02_1_M005': 'Oh no.  you know what I forgot?',
#  'Ses01F_script02_1_F002': 'What?',
#  'Ses01F_script02_1_M006': "My flashlight.  God, how could I be so stupid?  I can't believe I forgot my flashlight.",
#  'Ses01F_script02_1_F003': 'What flashlight?',
#  'Ses01F_script02_1_M007': "The flashlight, the silver one.  There's only one, isn't there?",
#  'Ses01F_script02_1_F004': "That's not your flashlight.",
#  'Ses01F_script02_1_M008': 'Whose is it?',
#  'Ses01F_script02_1_F005': "It's ours; it's my flashlight too.",
#  'Ses01F_script02_1_M009': 'Oh...well. Yeah, of course.',
#  'Ses01F_script02_1_F006': "You keep saying my flashlight like it's just yours.",
#  'Ses01F_script02_1_M010': 'No.',
#  'Ses01F_script02_1_F007': "How's that supposed to make me feel?",
#  'Ses01F_script02_1_M011': "Of course, our flashlight.  What's yours is mine.  Me flashlight es su flashlight.",
#  'Ses01F_script02_1_M012': 'Naturally.  God, how could we not think to bring it?  I hope the moon stays out, though.',
#  'Ses01F_script02_1_M013': "Do they always run during a full moon?  I don't remember.  Was it full last year?",
#  'Ses01F_script02_1_F008': 'Yeah.',
#  'Ses01F_script02_1_M014': 'Huh.  Are you cold?  Do you want my jacket?  No?  you know, we should have brought the blanket?  Our blanket.',
#  'Ses01F_script02_1_M015': 'Aw.  Do you know, I should have brought a six pack, too.  A six pack, that would be just the ticket right about now.  Huh?',
#  'Ses01F_script02_1_M016': "God, I'm so excited, I'm like a kid.  I can't believe I got out of the house with my fly zipped up.",
#  'Ses01F_script02_1_F009': '[LAUGHTER]',
#  'Ses01F_script02_1_M017': 'I wonder if they can hear me talk or like feel the vibrations in the sand when we move around.',
#  'Ses01F_script02_1_F010': "I'm cold.",
#  'Ses01F_script02_1_M018': 'Do you want my jacket?',
#  'Ses01F_script02_1_F011': "It's after eleven, let's go.",
#  'Ses01F_script02_1_M019': "What?  We just got here.  What's the point of coming all the way down here if we just turn around and go home?",
#  'Ses01F_script02_1_F012': 'There is no point.',
#  'Ses01F_script02_1_M020': 'Right.',
#  'Ses01F_script02_1_F013': "That's my point.",
#  'Ses01F_script02_1_M021': "Wait, that's my point, too.",
#  'Ses01F_script02_1_F014': "Well, then let's go.",
#  'Ses01F_script02_1_M022': "No, no.  Okay.  That's not my point.  My point is there is no point in coming down here if we just turn around and go home.  Don't you want to see it?",
#  'Ses01F_script02_1_F015': 'Not particularly.',
#  'Ses01F_script02_1_M023': 'Why not?',
#  'Ses01F_script02_1_F016': "I just don't.  It's stupid.",
#  'Ses01F_script02_1_M024': "Honey, this is like a natural phenomenon. I mean... People in Kansas would have to get plane reservations and get hotel rooms to see this.  It's just forty minutes away for us; it's too good to pass up.",
#  'Ses01F_script02_1_F017': 'Pass what up?  I mean these fish swim out of the ocean, they flop around on the beach, they swim away and then they die.',
#  'Ses01F_script02_1_M025': 'Yeah.  But this..this moment on the beach is like the highlight of their little lives.  All that flopping around is laying eggs or what to do - spawning or mating or whatever.',
#  'Ses01F_script02_1_M026': "This is a big night for these little guys.  It's like life's last orgy.",
#  'Ses01F_script02_1_F018': "I don't see why you're so excited; this isn't a freaking moon landing we are talking about.  It's fish.  It's a fish nobody even eats.",
#  'Ses01F_script02_1_M027': 'Yeah they do.',
#  'Ses01F_script02_1_F019': 'Oh Augie',
#  'Ses01F_script02_1_M028': "okay... well, Whatever.  But it's a fish who do something no other fish do.  It's like those swallows returning to Capistrano or like those lemmings that throw themselves off the cliffs.",
#  'Ses01F_script02_1_M029': "There's like mystery here, there's magic.  It's like a little bit of the unexplainable.  I just can't see how you're not interested.",
#  'Ses01F_script02_1_F020': "I'm just not.",
#  'Ses01F_script02_1_M030': 'For real?',
#  'Ses01F_script02_1_F021': 'Yeah.',
#  'Ses01F_script02_1_M031': "God, I don't get it.  you know the first time we came here, you said it was the best night of your life?",
#  'Ses01F_script02_1_M032': "And last year, I remember distinctly you said, you were so excited to get here that you don't remember you stubbed your toe until we were in the car.",
#  'Ses01F_script02_1_F022': "Last time, you'll also remember, we got our shoes wet, I got sand in my panties, you got a sore throat and we got into a big fight and we did not see the grunions.",
#  'Ses01F_script02_1_M033': "Ahh...we weren't in a good spot.",
#  'Ses01F_script02_1_F023': "Hmm.  We didn't see them the year before either.",
#  'Ses01F_script02_1_M034': "We just weren't in a good spot.  I'm telling you, this is a much better spot.  I have instincts for these things.",
#  'Ses01F_script02_1_M035': "Look there, see?  What's that?  No, that's - that's just seaweed.",
#  'Ses01F_script02_1_M036': 'God, this is great.  Think about this.  I know you are not interested, but just think about this.',
#  'Ses01F_script02_1_M037': "Right now out there, there is this mass of silver fish and it's heading this way.  No one sent them an invitation, no one told them, no one even gave them a map.",
#  'Ses01F_script02_1_M038': 'Just all at once, they turned and they formed this line as long as the California coast.  And some instinctual little firecracker went off in their bodies and they all just turned as one and started swimming.',
#  'Ses01F_script02_1_M039': 'They are swimming right now.  They are swimming as if that is the only thing that matters to them.',
#  'Ses01F_script02_1_M040': "It's single mindedness with no mind.  It is urgency that is just pure urge.",
#  'Ses01F_script02_1_M041': 'And they are swimming right now to this very point where we stand for this huge celebration of sex and death.',
#  'Ses01F_script02_1_M042': "Oh look.  I'm giving myself goose bumps, my hairs are standing up on my arm.",
#  'Ses01F_script02_1_F024': "That's the wind.",
#  'Ses01F_script02_1_M043': 'So what do you think?',
#  'Ses01F_script02_1_F025': 'About what?',
#  'Ses01F_script02_1_M044': 'About all of that, about all I was talking about.',
#  'Ses01M_script01_3_F000': 'The only one I know still love his parents.',
#  'Ses01M_script01_3_M000': "Yeah, that kind of went out of style didn't it?",
#  'Ses01M_script01_3_F001': "Oh it's not bad thing it's good thing.",
#  'Ses01M_script01_3_F002': "You know it's nice here, the air is sweet.",
#  'Ses01M_script01_3_M001': "You're not sorry you came?",
#  'Ses01M_script01_3_F003': "Not sorry, no.  I can't stay here.",
#  'Ses01M_script01_3_M002': 'Why not?',
#  'Ses01M_script01_3_F004': 'For one thing your mother as much as told me to go.',
#  'Ses01M_script01_3_M003': 'Well.',
#  'Ses01M_script01_3_F005': "[BREATHING] And then you've been kind of...",
#  'Ses01M_script01_3_M004': 'What?',
#  'Ses01M_script01_3_F006': "You've been kind of embarrassed ever since I got here.",
#  'Ses01M_script01_3_M005': "I was kind of planning on sneaking up on you, you know over like a course of a week or so. They just take for granted that we're already set.",
#  'Ses01M_script01_3_F007': 'I knew they would, your mother anyway.',
#  'Ses01M_script01_3_M006': 'You did?',
#  'Ses01M_script01_3_F008': 'From her point of view why else would I come?',
#  'Ses01M_script01_3_M007': 'Yeah--',
#  'Ses01M_script01_3_M008': "So then would you want to?  I mean I guess, you kind of have to know, maybe that's why I asked you to come.",
#  'Ses01M_script01_3_F009': "Well I guess that's why I came.",
#  'Ses01M_script01_3_M009': 'Ann, I love you.  I love you.',
#  'Ses01M_script01_3_M010': 'I love you a great deal.',
#  'Ses01M_script01_3_M011': "I'm sorry I don't really have much of an imagination.",
#  'Ses01M_script01_3_F010': 'Chris,',
#  'Ses01M_script01_3_M012': "I'm sorry I'm embarrassing you, aren't I?  See, I didn't want to do it here I didn't on this porch, with this ring--I didn't want to win you away from anything.",
#  'Ses01M_script01_3_F011': "I've been ready a long, long time.",
#  'Ses01M_script01_3_M013': "So then he's gone.  You sure?",
#  'Ses01M_script01_3_F012': 'I almost got married two years ago.',
#  'Ses01M_script01_3_M014': "Why didn't you?",
#  'Ses01M_script01_3_F013': 'You started to write me.',
#  'Ses01M_script01_3_M015': 'You felt something that far back?',
#  'Ses01M_script01_3_F014': 'Everyday since.',
#  'Ses01M_script01_3_M016': "why didn't you let me know?",
#  'Ses01M_script01_3_F015': 'Because I was waiting for you, Chris.  Till then you never wrote me and then when you did, well, you sure can be ambiguous you know.',
#  'Ses01M_script01_3_M017': "Oh Annie, why don't you go ahead and give me a kiss, come on just a...",
#  'Ses01M_script01_3_M018': 'I kissed you.  I kissed Annie.',
#  'Ses01M_script01_3_F016': "I'll never forgive you for waiting so long.  All I did was sit around and wonder if I was crazy for thinking about you.",
#  'Ses01M_script01_3_M019': 'I kissed you.',
#  'Ses01M_script01_3_F017': "Like Larry's brother.  Do what like you, Chris.",
#  'Ses01M_script01_3_F018': "Chris, what's the matter?",
#  'Ses01M_script01_3_M020': "Do you want to go somewhere?  Let's go.",
#  'Ses01M_script01_3_F019': 'No, what is it?  Is your mother?',
#  'Ses01M_script01_3_M021': "No, no, it's nothing like that.",
#  'Ses01M_script01_3_F020': 'Well, then what?  You know, even in your letter you seem kind of ashamed.',
#  'Ses01M_script01_3_M022': "I don't know it's--it's complicated. But it's going from me now.",
#  'Ses01M_script01_3_F021': 'You got to tell me.',
#  'Ses01M_script01_3_M023': "I don't know.",
#  'Ses01M_script01_3_M024': "It's kind of all mixed up with all these other things.",
#  'Ses01M_script01_3_F022': "Wouldn't work like this.",
#  'Ses01M_script01_3_M025': 'you know over seas I was in command of the company?',
#  'Ses01M_script01_3_F023': 'Yeah, sure.',
#  'Ses01M_script01_3_M026': 'Well I lost them.',
#  'Ses01M_script01_3_F024': 'How many?',
#  'Ses01M_script01_3_M027': 'Pretty much all.',
#  'Ses01M_script01_3_F025': '[BREATHING]. Geez.',
#  'Ses01M_script01_3_M028': "Takes awhile to toss something like that off.  I mean they weren't just men, you know.",
#  'Ses01M_script01_3_M029': 'For instance, there was this one time when this kid--it had been raining for like several days and he gave me his last pair of dry socks.',
#  'Ses01M_script01_3_M030': "He just put it in my pocket that's the kind of guys I had.",
#  'Ses01M_script01_3_M031': "They didn't die they killed themselves for each other and I mean that exactly, you know a little more selfish and they'll all be here today...",
#  'Ses01M_script01_3_M032': "And I had this idea as I was watching them go down like everything was being destroyed, you know.  But I felt like this one new thing was being made, you know it's kind of like this.  This monument...",
#  'Ses01M_script01_3_M033': 'You know, that they were bringing something on to this earth, a kind of sacrifice you know.',
#  'Ses01M_script01_3_M034': 'I thought I would change everything you know, and I got back here and it was- it was like nothing had changed at all...',
#  'Ses01M_script01_3_M035': 'You know.  I went to work with dad and I started that whole rat race again...',
#  'Ses01M_script01_3_M036': 'And no one had changed it was just like sort of random bus accident to them.',
#  'Ses01M_script01_3_M037': 'Driving my new car and I felt guilty you know opening my bank book seeing a new refrigerator.',
#  'Ses01M_script01_3_M038': "'Cause you can take those things out of a war.  But you have to realize that those things came out of the love that a man can have for another man...",
#  'Ses01M_script01_3_M039': "And if you can't see that then it's just loot and there's blood all over it.",
#  'Ses01M_script01_3_M040': "I felt ashamed and I didn't want any part of it.  I guess I included you too.",
#  'Ses01M_script01_3_F026': 'Do you still feel that way?',
#  'Ses01M_script01_3_M041': 'I want you to know Annie.',
#  'Ses01M_script01_3_F027': "'Cause you mustn't feel that way.  Everything you have, you have a right to...",
#  'Ses01M_script01_3_F028': 'Everything Chris do you understand that?  To me too...',
#  'Ses01M_script01_3_F029': "And your money there's nothing wrong in your money.  Your father put hundreds of planes into the air.  You should be proud of that a man should be paid for that.",
#  'Ses01M_script01_3_M042': 'Annie...',
#  'Ses01M_script01_3_M043': "I'm going to make a fortune for you.",
#  'Ses01M_script01_3_F030': 'What would I do with a fortune?',
#  'Ses01M_impro01_F000': 'Next.',
#  'Ses01M_impro01_M000': 'Yes, me. Okay, okay here we go.',
#  'Ses01M_impro01_F001': 'My window is open.',
#  'Ses01M_impro01_M001': 'Okay, so filled out all these forms  --',
#  'Ses01M_impro01_F002': 'This is... Your last- Your first name is Jones?',
#  'Ses01M_impro01_M002': 'and I have This form of ID here so...',
#  'Ses01M_impro01_M003': 'Yes, Jones.',
#  'Ses01M_impro01_F003': "That's just strange I figured you filled in wrong sections.",
#  'Ses01M_impro01_M004': 'Well...',
#  'Ses01M_impro01_F004': "What are you... what's...What are you applying for?",
#  'Ses01M_impro01_M005': "I'm just applying for another ID.",
#  'Ses01M_impro01_F005': 'Another ID?',
#  'Ses01M_impro01_M006': "Yes.  I'm supposed to have three forms of ID for this.  It's a long story, I'm supposed to have three forms of ID for this other job I really don't get into but I need another...",
#  'Ses01M_impro01_F006': 'Fine.  So I need ID.',
#  'Ses01M_impro01_M007': 'I have it right here, yes.',
#  'Ses01M_impro01_F007': 'No, I need your ID to give you a second ID.',
#  'Ses01M_impro01_F008': "It's really simple if you have a problem with it... Maybe you should--",
#  'Ses01M_impro01_M008': "But that's...",
#  'Ses01M_impro01_M009': "That's why I'm here, that's why I was waiting in this line.  I need to get another form of ID.",
#  'Ses01M_impro01_F009': 'Well, do you have your passport?',
#  'Ses01M_impro01_M010': "No, I don't have a passport.",
#  'Ses01M_impro01_F010': 'You have a birth certificate?',
#  'Ses01M_impro01_M011': "I don't where it is though, I don't have with me.  Can I get it from somewhere?  I mean...",
#  'Ses01M_impro01_F011': 'What do you expect me to do?',
#  'Ses01M_impro01_M012': "I probably have to go wait another line to get my birth certificate don't I?",
#  'Ses01M_impro01_F012': 'Probably.',
#  'Ses01M_impro01_M013': "You're very helpful.  What's your name?",
#  'Ses01M_impro01_F013': 'Joy.',
#  'Ses01M_impro01_M014': 'Hi, Joy.',
#  'Ses01M_impro01_F014': 'Hi.   You know...',
#  'Ses01M_impro01_M015': 'So can you help me or not?',
#  'Ses01M_impro01_F015': "I am..I don't..I don't understand what you want.  A driver's license or a California ID.",
#  'Ses01M_impro01_M016': 'Okay. [BREATHING]',
#  'Ses01M_impro01_M017': 'I need California ID.',
#  'Ses01M_impro01_F016': 'Okay.',
#  'Ses01M_impro01_M018': 'On top of these other two forms of ID which I already have.',
#  'Ses01M_impro01_F017': "What... well, do you have a driver's license?",
#  'Ses01M_impro01_M019': "No, I don't have driver's license.",
#  'Ses01M_impro01_F018': 'Then how am I supposed to give you a California ID?',
#  'Ses01M_impro01_M020': 'Did you even look at the form?  I filled it out all these questions--',
#  'Ses01M_impro01_F019': "Don't raise your voice with me.",
#  'Ses01M_impro01_M021': "Did you even look at the form?  I've already answered these question.",
#  'Ses01M_impro01_F020': "Don't talk to me like I'm a child.",
#  'Ses01M_impro01_M022': 'Okay.',
#  'Ses01M_impro01_F021': "Do you know how long I've been working here? How long have you lived in California?",
#  'Ses01M_impro01_M023': 'If it makes you stop acting like a child.',
#  'Ses01M_impro01_M024': 'I have been to California my whole--',
#  'Ses01M_impro01_F022': 'Maybe you never been to the D.M.V. before, maybe you should get back in line.  You know what?  sit in line again and if you get my number ask for different one.',
#  'Ses01M_impro01_M025': "I am not...I'm not getting to back that line.",
#  'Ses01M_impro01_M026': "Okay, okay let's keep our voices down, okay?  I didn't come here to get in yelling match.",
#  'Ses01M_impro01_F023': "I'm perfectly calm.",
#  'Ses01M_impro01_M027': 'I did not come in here to get in a yelling match with you, all right?',
#  'Ses01M_impro01_F024': "Uh huh.  I didn't come here get in yelling match either.",
#  'Ses01M_impro01_M028': 'Just try and help me.',
#  'Ses01M_impro01_F025': "They don't pay me enough to deal people like you.",
#  'Ses01M_impro01_M029': 'People like me, what is that supposed to mean?  You know, this is ridiculous.  Is there like a manager here, is there someone else that I can talk to?',
#  'Ses01M_impro01_F026': 'Why?',
#  'Ses01M_impro01_M030': 'Why?',
#  'Ses01M_impro01_F027': 'Yeah.',
#  'Ses01M_impro01_F028': "So you're not going to send me a thank you card, is that a problem? Is your are not going...",
#  'Ses01M_impro01_M031': "Why, because I'm sick of talking to you.",
#  'Ses01M_impro01_M032': "'Cause you're obviously not talking to me, you're just yelling at me, berating me and telling me I can't fill out forms right.",
#  'Ses01M_impro01_F029': 'Oh, dear. Oh, boo-foo-woo, foo-foo.',
#  'Ses01M_impro01_M033': "Oh, no honey. And you're going to miss the Christmas card too. It's a shame. It's going to be a good, nice picture.",
#  'Ses01M_impro01_F030': 'Sit back down.',
#  'Ses01M_impro04_F000': 'You seem kind of down.',
#  'Ses01M_impro04_M000': "I'm just mad.",
#  'Ses01M_impro04_F001': 'How come?',
#  'Ses01M_impro04_M001': "It's--I've been trying to find this job I can't get any job.",
#  'Ses01M_impro04_M002': "It's not fair.",
#  'Ses01M_impro04_F002': 'What do you mean?',
#  'Ses01M_impro04_M003': "I mean I've been looking for a job for like three years and I can't get a job.  I mean like, it's America, right?  I should be able to get a job.",
#  'Ses01M_impro04_F003': "There's a lot of people looking for jobs.",
#  'Ses01M_impro04_M004': "I guess.  But three years?  I mean, I like--I went to college even, I mean I didn't finish but I went for like a little bit.  It's not fair, I don't know.",
#  'Ses01M_impro04_F004': "I don't know, I mean, I just don't think...",
#  'Ses01M_impro04_M005': "I mean I've been sending out my resumes and doing everything I can do but nothing is happening.  You know, it's like I can't and I can't keep living on loans anymore like this.  I'm going to--I mean eventually I'm going to have to pay it back. I'm just kind of freaking out, I don't know.",
#  'Ses01M_impro04_F005': "Did you ever think it might be your attitude that's...",
#  'Ses01M_impro04_M006': 'What\'s my--like what do you mean "my attitude"?',
#  'Ses01M_impro04_F006': "I don't know just sometimes you get kind of... No, I'm not saying that.  I just--",
#  'Ses01M_impro04_M007': 'Do I have an attitude problem?',
#  'Ses01M_impro04_M008': "No, well maybe it's because I'm like frustrated 'cause I can't get a job, you know.",
#  'Ses01M_impro04_F007': '...has anyone ever just said anything like that to you before?',
#  'Ses01M_impro04_M009': "Like it's really hard to like shake that off when you go into like audition a room or whatever, you know what I mean?",
#  'Ses01M_impro04_F008': 'Right, sure.',
#  'Ses01M_impro04_F009': "But I mean you kind of got to, you got to fake it 'til you feel it, right?",
#  'Ses01M_impro04_M010': 'I guess I just getting really hard to fake, you know.',
#  'Ses01M_impro04_F010': "I'm just saying that if I was looking to hire somebody in the--or kind of... No. No. No.",
#  'Ses01M_impro04_M011': 'Are you hiring? Wait, do you know of a job? Seriously, do you know, like do you know of anything though?  Like, oh please, do you know of anything?',
#  'Ses01M_impro04_F011': "No.  I'm just saying though that if I was a person who was hiring somebody I-- --would not hire someone who was angry or upset.",
#  'Ses01M_impro04_M012': 'Yeah.',
#  'Ses01M_impro04_M013': 'I come across angry?',
#  'Ses01M_impro04_F012': 'No.',
#  'Ses01M_impro04_M014': 'What?',
#  'Ses01M_impro04_F013': 'Well, you know a little.  If you were to listen to--',
#  'Ses01M_impro04_M015': "Okay.  You're my friend you can tell me stuff.  You can tell me honestly stuff, okay?  Please.",
#  'Ses01M_impro04_F014': "I just don't want you to fly off the handle.",
#  'Ses01M_impro04_M016': "Okay, I'm not flying off the handle I don't think I'm flying off the handle here at all.",
#  'Ses01M_impro04_F015': 'You kind of have a short fuse.',
#  'Ses01M_impro04_M017': 'I have a short fuse?',
#  'Ses01M_impro04_F016': 'Yeah.',
#  'Ses01M_impro04_M018': 'Okay. Okay no, no, no, no okay no, I need to hear this more. Come on, bring it.',
#  'Ses01M_impro04_F017': "Like this, right now we're trying have a conversation.",
#  'Ses01M_impro04_F018': "We're trying to have a conversation and you seem extremely hostile. You keep cutting me off.",
#  'Ses01M_impro04_M019': "Well, it's 'cause I can't get a job, okay?",
#  'Ses01M_impro04_M020': "I'm not always right I'm just--",
#  'Ses01M_impro04_F019': "I can't finish the sentence with you without you jumping in...",
#  'Ses01M_impro04_F020': "...and you're always right.",
#  'Ses01M_impro04_M021': 'fine okay.',
#  'Ses01M_impro04_F021': 'You have an excuse for everything.',
#  'Ses01M_impro04_M022': '[BREATHING]',
#  'Ses01M_impro04_F022': "I'm just saying that maybe you should take in some information before you produce more of your own.",
#  'Ses01M_impro04_M023': "I'm like a sponge I'm like soaked up with all this information for like three years I'm just dying for a job to like put it in to.",
#  'Ses01M_impro04_F023': '[BREATHING]',
#  'Ses01M_impro04_F024': "That's -.",
#  'Ses01M_impro04_M024': "You know, and like I don't think it's that much to ask. I know.",
#  'Ses01M_impro04_F025': 'Well, what kind of field are you looking to go into?',
#  'Ses01M_impro04_M025': "That's it.",
#  'Ses01M_script03_1_M000': 'Good God.',
#  'Ses01M_script03_1_F000': "Do you think it's them?",
#  'Ses01M_script03_1_M001': 'I wonder.',
#  'Ses01M_script03_1_F001': "Freda is the only one who knows we are here. She wouldn't ring up.",
#  'Ses01M_script03_1_M002': 'Must be them then.',
#  'Ses01M_script03_1_F002': "What we're going to do?",
#  'Ses01M_script03_1_M003': "We're okay, right darling?  Whatever happens, we're okay?",
#  'Ses01M_script03_1_F003': 'Now and always sweet.',
#  'Ses01M_script03_1_M004': "I don't care then.",
#  'Ses01M_script03_1_F004': 'It had to happen sooner or later.',
#  'Ses01M_script03_1_M005': "Yes... Hello?  Hello?  I'm sorry what's that?",
#  'Ses01M_script03_1_M006': "No, it's a wrong number.",
#  'Ses01M_script03_1_F005': 'Oh, oh, that sent shivers on my spine.',
#  'Ses01M_script03_1_M007': '[BREATHING] [LAUGHTER]',
#  'Ses01M_script03_1_F006': 'Oh...',
#  'Ses01M_script03_1_M008': '[BREATHING]',
#  'Ses01M_script03_1_F007': '[BREATHING]',
#  'Ses01M_script03_1_M009': 'What shall we do if they suddenly walk in on us?',
#  'Ses01M_script03_1_F008': 'Oh. Behave exquisitely...',
#  'Ses01M_script03_1_M010': 'With perfect poise...',
#  'Ses01M_script03_1_F009': '[LAUGHTER] I think I shall do a court curtsey.',
#  'Ses01M_script03_1_M011': 'Ah...',
#  'Ses01M_script03_1_F010': '[LAUGHTER]',
#  'Ses01M_script03_1_M012': 'Ah...Strange...',
#  'Ses01M_script03_1_F011': 'Mmm...',
#  'Ses01M_script03_1_M013': "Things that just ought to matter dreadfully, you know they just don't matter at all when one is happy, do they?",
#  'Ses01M_script03_1_F012': "The pity is that one can't stay happy.",
#  'Ses01M_script03_1_M014': "Darling, don't say that.",
#  'Ses01M_script03_1_F013': "It's true.  I think the whole things a very poor joke.",
#  'Ses01M_script03_1_M015': 'What, this sacred and beautiful thing, love?',
#  'Ses01M_script03_1_F014': 'Oh, yes meaning just that.',
#  'Ses01M_script03_1_M016': 'Oh, dear god what is that all mean, dear god?',
#  'Ses01M_script03_1_F015': "[LAUGHTER] Don't laugh at me I'm being serious.",
#  'Ses01M_script03_1_M017': "You mustn't be so serious, darling, it just what they want.",
#  'Ses01M_script03_1_F016': 'Oh whose they?',
#  'Ses01M_script03_1_M018': 'Oh you know all those superficial philosophers. We must laugh at them, be flippant.',
#  'Ses01M_script03_1_M019': 'Flippancy brings out the acid in their darn sweetness and light.',
#  'Ses01M_script03_1_F017': 'Mmhmm If I must laugh at everything, I must laugh at us too.',
#  'Ses01M_script03_1_M020': 'Oh yes.  .',
#  'Ses01M_script03_1_F018': 'How long will it last, this ludicrous, overbearing love of ours?',
#  'Ses01M_script03_1_M021': 'We are figures of fun all right',
#  'Ses01M_script03_1_M022': 'Ahh...who knows.',
#  'Ses01M_script03_1_F019': 'Shall we always want to bicker and fight?',
#  'Ses01M_script03_1_M023': 'No, that will fade...Along with our passion...',
#  'Ses01M_script03_1_F020': 'Oh, will we like that?',
#  'Ses01M_script03_1_M024': "Well it depends on how well we've played.",
#  'Ses01M_script03_1_F021': 'If one of us dies...',
#  'Ses01M_script03_1_F022': "does the one that's left still laugh?",
#  'Ses01M_script03_1_M025': 'Yes, yes with the all his might.',
#  'Ses01M_script03_1_F023': "Well, that's serious enough isn't it?",
#  'Ses01M_script03_1_M026': "No, no, no, no death is very laughable it's a cunning little mystery, you know.  It's all done with mirrors.",
#  'Ses01M_script03_1_F024': "I think you're talking nonsense.",
# ...
#  'Ses01M_impro05_F002': 'What- What flight did you come in on?',
#  'Ses01M_impro05_M002': "Okay, I'm coming in from Atlanta.",
#  'Ses01M_impro05_F003': 'Georgia?',
#  'Ses01M_impro05_M003': 'Yes, Georgia.  Good for you I need my bag.  Can you...',
#  'Ses01M_impro05_F004': "There's no need for you to raise your voice, sir.",
#  'Ses01M_impro05_F005': "I've been college educated.",
#  'Ses01M_impro05_F006': 'I speak your language.',
#  'Ses01M_impro05_M004': "Are you insinuating that I don't have a college education and that- for some reason that makes you a better person than I am?",
#  'Ses01M_impro05_M005': "Listen, shut your smug mouth, okay?  I don't need that.",
#  'Ses01M_impro05_F007': "I'm just saying you don't need to talk to me like I-",
#  'Ses01M_impro05_M006': "I've been sitting here for four hours.",
#  'Ses01M_impro05_F008': "I'm not a child.",
#  'Ses01M_impro05_F009': "I've been here for sixteen.",
#  'Ses01M_impro05_M007': 'You people have just been tossing me around like a used hanky.',
#  'Ses01M_impro05_F010': 'I come here every single day.',
#  'Ses01M_impro05_M008': 'You work here.',
#  'Ses01M_impro05_F011': 'Details, Details.  Well, anyhow can I--',
#  'Ses01M_impro05_F012': 'so you flew in from Atlanta...',
#  'Ses01M_impro05_M009': 'My bag from Atlanta.',
#  'Ses01M_impro05_F013': 'Four...Four hours ago.',
#  'Ses01M_impro05_M010': "It's a little black bag with wheels.",
#  'Ses01M_impro05_F014': 'Do you have any i-?',
#  'Ses01M_impro05_M011': "That you wouldn't let me put in the overhead compartment.  You said I had to check it.",
#  'Ses01M_impro05_F015': "I wouldn't let you?   I was not in Atlanta. I was not in Atlanta.",
#  'Ses01M_impro05_M012': "It's a tiny little bag.",
#  'Ses01M_impro05_F016': "I had nothing to do with the boarding attendance.  I'm sorry that your seat was wherever it was.",
#  'Ses01M_impro05_M013': 'It was right in the middle of five different people.  I had a huge fat lady next me, a crying kid on left I went like can I please get a Bloody Mary, please? Will you bring a Bloody Mary?',
#  'Ses01M_impro05_F017': "I have some unfortunate news, uh, that your bag isn't going to be--",
#  'Ses01M_impro05_F018': '--arriving any time soon.',
#  'Ses01M_impro05_M014': 'Just had a really, really stressful day, okay?  And I need my bag; can you please help me get my bag?',
#  'Ses01M_impro05_F019': "I'm really sorry to tell you this but...",
#  'Ses01M_impro05_M015': 'Okay.',
#  'Ses01M_impro05_F020': "It's not.  I can offer you fifty dollars and a reimbursement gift cards for our airline...",
#  'Ses01M_impro05_F021': '...and your future...',
#  'Ses01M_impro05_M016': "I'm sorry, wait a minute.  Are you saying I'm not going to get my bag at all?",
#  'Ses01M_impro05_F022': 'No.',
#  'Ses01M_impro05_M017': "It's gone.",
#  'Ses01M_impro05_F023': 'Yes.',
#  'Ses01M_impro05_M018': 'Where is it?  Where did it go?',
#  'Ses01M_impro05_F024': "We've actually...",
#  'Ses01M_impro05_M019': 'You mean did someone steal it? Do people steal bags?',
#  'Ses01M_impro05_F025': "They do as matter of fact.  We don't like to publicize it because",
#  'Ses01M_impro05_F026': "people wouldn't Fly our airline.",
#  'Ses01M_impro05_M020': 'Probably people that work for your company huh?',
#  'Ses01M_impro05_M021': 'Do you know what was in that little bag that I could have just easily put in overhead compartment but no I had to check?',
#  'Ses01M_impro05_F027': 'What was that?',
#  'Ses01M_impro05_M022': "My computer which has all of my data which I'm collecting right now.",
#  'Ses01M_impro05_F028': "That's unfortunate.",
#  'Ses01M_impro05_M023': "Yeah it's really unfortunate you know why because I'm going to get fired if I don't get that.  So I need to have that back.",
#  'Ses01M_impro05_F029': "That's too bad.",
#  'Ses01M_impro05_M024': 'Fifty dollars is not going to cover me for my job, okay?',
#  'Ses01M_impro05_F030': 'I wish I could give it to you.',
#  'Ses01M_impro05_M025': "Well you need to find it. Can I just go back there and look through the bags?  Can I just go back there and just go through maybe I'll find it.",
#  'Ses01M_impro05_F031': 'I wish I-',
#  'Ses01M_impro05_F032': "That's not - no.",
#  'Ses01M_impro05_F033': 'No.',
#  'Ses01M_impro05_M026': "It'll be a lot more than what you're doing sitting here and just give me lip service.  I'd like to go back at least do some aggressive searching for my stuff.",
#  'Ses01M_impro05_F034': "We have plenty of aggressive searching going on it's not there.  Someone's taken it.",
#  'Ses01M_impro05_M027': 'Sure, yeah right you have plenty of aggressive searching going on, aggressive searching, drinking coffee and smoking cigarettes.',
#  'Ses01M_impro05_M028': "I know what you guys do when you're not working you're union people; you just sit around on your ass.",
#  'Ses01M_impro05_F035': "You know I don't need to take this sort of abuse.",
#  'Ses01M_impro05_M029': "Well, I don't need to take this kind of abuse either.  I just was trying get back to Atlanta. I just got home, I just want to get my bag and get my stuff. And keep my job.",
#  'Ses01M_impro05_F036': "That's fantastic.",
#  'Ses01M_impro05_F037': "Then why don't you take your fifty dollars. Get yourself a taxi and go shopping tomorrow.",
#  'Ses01M_impro05_M030': '[BREATHING]',
#  'Ses01M_impro05_M031': 'Thank you very much.',
#  'Ses01F_script03_1_M000': 'Good God.',
#  'Ses01F_script03_1_F000': 'Is it them?',
#  'Ses01F_script03_1_M001': 'I wonder.',
#  'Ses01F_script03_1_F001': "Freda is the only one who knows we are here.  She wouldn't ring up.",
#  'Ses01F_script03_1_M002': 'It must be them then.',
#  'Ses01F_script03_1_F002': 'It had to happen sooner or later.  What are we going to do?',
#  'Ses01F_script03_1_M003': '[BREATHING]',
#  'Ses01F_script03_1_M004': "We are okay, aren't we darling?",
#  'Ses01F_script03_1_F003': 'Now and always, sweet.',
#  'Ses01F_script03_1_M005': "I don't care then.",
#  'Ses01F_script03_1_F004': 'It had to happen sooner or later.',
#  'Ses01F_script03_1_M006': "Hello?  Hello?  I'm sorry, what's that?",
#  'Ses01F_script03_1_M007': 'No.  Wrong number. [LAUGHTER]',
#  'Ses01F_script03_1_F005': '[LAUGHTER] That sent shivers up my spine.',
#  'Ses01F_script03_1_M008': 'What shall we do if they suddenly walk in on us.[LAUGHTER]',
#  'Ses01F_script03_1_F006': "We'll behave exquisitely.",
#  'Ses01F_script03_1_M009': 'With perfect poise.',
#  'Ses01F_script03_1_F007': 'I think I shall do a curtsy.',
#  'Ses01F_script03_1_M010': "It's strange; things that ought to matter dreadfully, they just don't matter at all when one's happy.  Do they?",
#  'Ses01F_script03_1_F008': "Hmm.  The pity is that one can't stay happy.",
#  'Ses01F_script03_1_M011': "Darling, don't say that.",
#  'Ses01F_script03_1_F009': "It's true.  I think the whole thing's a cruel joke.",
#  'Ses01F_script03_1_M012': 'What?  This beautiful and sacred thing - love?',
#  'Ses01F_script03_1_F010': 'Yes.  Meaning just that.',
#  'Ses01F_script03_1_M013': "Well what does it all mean?  That's what I ask myself in my quest for ultimate truth.  Dear God, what does it all mean?",
#  'Ses01F_script03_1_F011': "Don't laugh at me.  I'm being serious.",
#  'Ses01F_script03_1_M014': "Oh darling, you mustn't be serious.  It's just what they want.",
#  'Ses01F_script03_1_F012': "Who's they?",
#  'Ses01F_script03_1_M015': 'All of those futile moralists who make life unbearable.  You have to laugh at them, be flippant.',
#  'Ses01F_script03_1_M016': 'You know, flippancy brings out the acid in their darned, light and sweetness.',
#  'Ses01F_script03_1_F013': 'you know if I laugh at everything then I must laugh at us, too.',
#  'Ses01F_script03_1_M017': 'Oh of course.  We are figures of fun.  All right.',
#  'Ses01F_script03_1_F014': 'How long with it last, this ludicrous overbearing love of ours?',
#  'Ses01F_script03_1_M018': 'Who knows?',
#  'Ses01F_script03_1_F015': 'Shall we always want to bicker and fight?',
#  'Ses01F_script03_1_M019': 'Oh no.  That fire will fade along with our passion.',
#  'Ses01F_script03_1_F016': 'Oh dear, should we like that?',
#  'Ses01F_script03_1_M020': "Well it depends on how well we've played.",
#  'Ses01F_script03_1_F017': 'What happens if one of us dies?  Does the other one still laugh?',
#  'Ses01F_script03_1_M021': 'Yes.  Yes with all of his might.',
#  'Ses01F_script03_1_F018': "Well that's serious enough, isn't it?",
#  'Ses01F_script03_1_M022': "No, no, no, no. no.  Death is a very laughable thing.  It's a cunning little mystery, it's all done with mirrors.",
#  'Ses01F_script03_1_F019': 'I think you are talking nonsense.',
#  'Ses01F_script03_1_M023': 'Oh.  So is everyone, in the long run.',
#  'Ses01F_script03_1_M024': "Let's be superficial, and just pity those poor philosophers, huh?  Let's blow trumpets and squeakers and enjoy the party for as long as we can, you know, like small, idiotic school children.",
#  'Ses01F_script03_1_F020': '[LAUGHTER]',
#  'Ses01F_script03_1_M025': 'Oh Come and kiss me darling before your body rots and worms pop out of your eye sockets.',
#  'Ses01F_script03_1_F021': "Oh Elliott, worms don't pop.",
#  'Ses01F_script03_1_M026': "Oh See, I don't care what you do, see.  You can paint yourself green and run naked through the Place Vendome and run off with all of the men of the world.  I shan't say a word, just as long as you love me best.",
#  'Ses01F_script03_1_F022': "Aw.  Thank you, darling.  The same applies to you too, except that if you so much as look at another woman I'll kill you.",
#  'Ses01F_script03_1_M027': 'Do you remember that awful scene we had in Venice?',
#  'Ses01F_script03_1_F023': 'Which particular one?',
#  'Ses01F_script03_1_M028': 'The one where you put that tiny painted wooden snake in my bed.',
#  'Ses01F_script03_1_F024': 'Oh Charles, that was his name.  He did wiggle so beautifully.',
#  'Ses01F_script03_1_M029': '[GARBAGE]',
#  'Ses01F_script03_1_M030': 'It was a terrible thing.  I hated it.',
#  'Ses01F_script03_1_F025': "I know you did.  You threw him out the window into the Grand Canal.  I'll never forgive you for that.",
#  'Ses01F_script03_1_M031': 'How long did that row last?',
#  'Ses01F_script03_1_F026': 'It went on intermittently for days.',
#  'Ses01F_script03_1_M032': 'Uh huh.',
#  'Ses01F_script03_1_M033': 'But the worst one was in Cannes when your curling irons burnt a hole in my new dressing gown.',
#  'Ses01F_script03_1_F027': 'Oh And it burnt my comb, too, and all of those towels in the bathroom.',
#  'Ses01F_script03_1_M034': "That was a rouser, wasn't it?",
#  'Ses01F_script03_1_F028': '[LAUGHTER] That was the first time you hit me.',
#  'Ses01F_script03_1_M035': 'I did not hit you very hard.',
#  'Ses01F_script03_1_F029': 'The manager came in, he found us rolling about the floor, biting and scratching like panthers. [LAUGHTER]  How utterly, utterly ridiculous.',
#  'Ses01F_script03_1_M036': "[LAUGHTER] I'll never forget his face. [LAUGHTER]",
#  'Ses01F_script03_1_M037': '[LAUGHTER] We were very much younger then.',
#  'Ses01F_script03_1_F030': '[LAUGHTER] And very much sillier.',
#  'Ses01F_script03_1_M038': 'However I believe the real cause of that row was Peter Burden.',
#  'Ses01F_script03_1_F031': 'Oh.  You knew there was nothing in that.',
#  'Ses01M_script01_1_F000': "What he's going to say?",
#  'Ses01M_script01_1_M000': 'He saw it.',
#  'Ses01M_script01_1_F001': 'When?',
#  'Ses01M_script01_1_M001': 'He was out here at four this morning.',
#  'Ses01M_script01_1_F002': 'How could he see it?  I was the first one up and he was still in bed.',
#  'Ses01M_script01_1_M002': 'I was out here at four this morning I heard a crack and I looked out the window and he was standing right over there.',
#  'Ses01M_script01_1_F003': 'What was he doing here at four in the morning?',
#  'Ses01M_script01_1_M003': "I don't know.  But he went back in the kitchen and he cried.",
#  'Ses01M_script01_1_F004': 'Did you talk to him?',
#  'Ses01M_script01_1_M004': "No.  I figured I'd just let it wait.",
#  'Ses01M_script01_1_F005': 'Cried hard?',
#  'Ses01M_script01_1_M005': 'Yeah, I could hear him crying through the floorboards in my room.',
#  'Ses01M_script01_1_F006': '[BREATHING]',
#  'Ses01M_script01_1_F007': 'What is he doing out here at that hour?',
#  'Ses01M_script01_1_M006': "I don't know.",
#  'Ses01M_script01_1_F008': "He's dreaming about him again, walking the streets.",
#  'Ses01M_script01_1_M007': 'I guess he is.',
#  'Ses01M_script01_1_F009': "It's getting to be just like after he died.  What is the meaning of that?",
#  'Ses01M_script01_1_M008': "I don't know the meaning of it.  But I know we've made terrible mistake with father.",
#  'Ses01M_script01_1_F010': 'What?',
#  'Ses01M_script01_1_M009': 'I mean, these kinds of things, man they always come back at you.  And this is definitely coming back to us.',
#  'Ses01M_script01_1_F011': 'What do you mean a mistake?',
#  'Ses01M_script01_1_M010': "I just--why shouldn't he walk the nights waiting for him, huh?  Do we contradict him do we say we don't have any hope any more that he's not coming back?",
#  'Ses01M_script01_1_F012': 'What do you want to do, argue with him?',
#  'Ses01M_script01_1_M011': "I don't want to argue with him, it's just for God's sake it's time he realized that no one believes with him any more.",
#  'Ses01M_script01_1_F013': "You can't say that to him.",
#  'Ses01M_script01_1_M012': 'I got to.',
#  'Ses01M_script01_1_F014': 'What, can you prove it?  What proof do you have?  Can you prove it?',
#  'Ses01M_script01_1_M013': "For God's sake, three years?  Nobody comes back after three years. It's insane.",
#  'Ses01M_script01_1_F015': "To you it is, to me it is.  But to your father?  You can talk yourself 'til you're blue in the face but there's was no grave and there is no body.  So where are you?",
#  'Ses01M_script01_1_M014': 'Okay, all right.  Mom, sit down.  I want to talk to you.',
#  'Ses01M_script01_1_F016': 'The trouble is those god damn news papers.  Every month some boy comes back missing longer then Larry so--',
#  'Ses01M_script01_1_M015': 'Yeah, okay all right, all right.  Listen, um, you know why I asked Annie here, right?',
#  'Ses01M_script01_1_F017': 'Why?',
#  'Ses01M_script01_1_M016': 'You know.',
#  'Ses01M_script01_1_F018': "Well, I've got an idea but what's the story?",
#  'Ses01M_script01_1_M017': "I'm going to ask her to marry me.",
#  'Ses01M_script01_1_F019': "Well, that's only your business, Chris.",
#  'Ses01M_script01_1_M018': "You know it's not just my business.",
#  'Ses01M_script01_1_F020': "Well, what do you want me to do?  You're old enough known your own business.",
#  'Ses01M_script01_1_M019': "So it's okay then?  I'm just going to go ahead with it?",
#  'Ses01M_script01_1_F021': "You want to make sure that your father's not going to...",
#  'Ses01M_script01_1_M020': "See.  Then it's not just my business. Sometimes you infuriate me, you know that?  You know it's just your business too if I tell father and he throws a fit about it, huh?",
#  'Ses01M_script01_1_F022': "I'm just saying.",
#  'Ses01M_script01_1_F023': "I'm sorry.  I ignore what I've got to ignore. That girl is Larry's girl.",
#  'Ses01M_script01_1_M021': "She is not Larry's girl.",
#  'Ses01M_script01_1_F024': "From father's point of view he is not dead and you have no right to take his girl.  I'm just saying that you can go on from there if you know where to go but I'm saying I don't know where to go.  See, I don't know.",
#  'Ses01M_script01_1_M022': "I don't know why it is you know every time I reach out for something I have to pull back 'cause I'm afraid it's going to hurt somebody.  All my life...",
#  'Ses01M_script01_1_F025': "You're a considerate fellow.  There's nothing wrong in that.",
#  'Ses01M_script01_1_M023': 'To hell with that.',
#  'Ses01M_script01_1_F026': 'Did you ask Annie yet?',
#  'Ses01M_script01_1_M024': 'No, I wanted to get this all sorted out first.',
#  'Ses01M_script01_1_F027': "Well, how do you know she's going to marry you?  Maybe she feels same way your father does.",
#  'Ses01M_script01_1_M025': "Well, if she does then that's the end of it.  However from her letters I think she's pretty much forgotten him.",
#  'Ses01M_script01_1_F028': "The trouble is you don't see enough women, you never did.",
#  ...}

# %%
import pandas as pd
import numpy as np
import pickle
import re

import itertools
import xgboost as xgb
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score

from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#local_df = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/df_iemocap.csv')
#x_train, x_test = train_test_split(local_df, test_size=0.20)

# %%
x_train, x_test = train_test_split(df, test_size=0.20)

# %%
x_train['wav_file']
# Out:
# 4973       Ses03M_impro02_M025
# 1302    Ses01F_script03_1_F020
# 1805    Ses01M_script01_3_M031
# 149     Ses01M_script01_2_M003
# 6890       Ses04F_impro07_M035
#                  ...
# 4403    Ses03F_script02_1_M015
# 5999    Ses04M_script03_2_F027
# 5134       Ses03F_impro07_M023
# 1470       Ses01M_impro02_M007
# 3860    Ses03F_script01_1_M035
# Name: wav_file, Length: 6018, dtype: object

# %%
for code in x_train['wav_file']:
  print(normalizeString(audiocode2text[code]))
# Out:
# Streaming output truncated to the last 5000 lines.
# yeah .
# last year you will also remember our shoes got wet . i got sand in my panties . we got into a big fight over nothing . you got a sore throat and we did not see the grunions .
# oh i am . let go of me .
#  laughter it s gotta be it like
# she s been in new york three and half years why all of a sudden
# you started to write me .
# okay . but how do i that s that s not proof to me . how do i know that you know that it s really you . i need
# now what s going to happen to your father do you know ? i don t .
# it was in the car right ? driving past the knickerbocker liquor locker ? you said let s get some champagne and i said times a wasting or something like that . right ? that s it right ? you want this to be like the other time . that s it . of course .
# the trouble is i planned on sort of sneaking up on you on a period of a week or so . but they take it for granted that we re all set .
# that s serious enough .
# i mean i just don t i don t know . if you don t have a lot of qualification where do you where do you find work ? it s like l .a . is so frustrating because if you don t know somebody you can t you can t get a job . it s impossible . it s totally discriminatory . you have to know somebody .
# you didn t did you tell them you have two young children at home ?
# everybody is believes that it keeps them excited you know it keeps them coming back for more .
# for heavens sake this isn t about fish .
# it s sort of it s almost better off to rest in peace than he is to live in pain .
# is there a funeral planned ? or
# they are away in tunis .
# for instance one time this . . .it had been raining several days and this one kid he came up to me he gave me his last pair of dry socks put them in my pocket .
# that s helpful .
#  breathing
# i m sorry .
# okay okay .
# well maybe you should
# you re quite insufferable . i expect it s because you re drunk .
# to bring that on to the earth again you know is like some kind of monument and i thought i would just make a difference to them .
# otherwise what you have here is loot and there s blood on it .
# well let me just check on that for you . where are you coming ?
# you want my jacket ?
# actually now that you mention it . no i don t .
# about four this morning . i heard it crack and i looked out the window and he was standing right there when it cracked .
# and last year i remember like distinctively you were so excited to get here that you didn t realize you stubbed your toe until we were in a car .
# what is the matter with you ?
# party .
# if we are really quiet the fish might come .
# i know that augie i really do .
# it s your fault cause cause you always told me to to do this and i did that instead . and i didn t take your advice and and but you sort of were like were telling
# twice is every time we ve tried that s ever .
# really amanda .
#  laughter why did she pick you ? where were you ?
# so could i maybe get the form from you fill it out here and maybe you could
# and he could of . . . he was pretty awesome
# yeah i suppose i have been . but it s going from me .
# joe do you think he knew i loved him ?
# you got to tell me .
# what the hell is this are you crazy ?
# you know why i asked annie here right ?
# no no . this is real .
# i think that s kind of stupid that you put a hundred thousands of dollars in the bag .
# yea .
# there s like mystery here there s magic . it s like a little bit of the unexplainable . i just can t see how you re not interested .
# hi . um my luggage didn t come out of the conveyor thingy .
# you feel it s wrong here don t you ? this yard this chair . i want you to be ready for me . i don t want to have to win you away from anything .
# i got to freak her out .
# ma am please calm down . when you purchase a ticket there is a terms and agreement
# you knew there was nothing in that .
# we ve got to say it to him .
# it s my fault cause you didn t do what i told you to ?
# ma am i understand that .
# i don t know .
# is that is that nah is that just paul ? i can t even tell .
# i m sorry there is no guarantee on baggage .
# you re my best friend we re growing up and now you re getting married . that s amazing
# come just please just grab the form . it s right over there .
# this woman came up and you know it was hers . it was her person that was there .
# well but you care about what you do right ?
# you
# i don t see why it has to be annie .
# let s drive somewhere . i want to be alone with you .
# the what the i mean
# what is he doing out here at that hour ?
# it s just you know i ve had this problem before . you re not the first person to tell me that i need a resume but . . .
# fine . it s dorky .
# awesome .
#  . . .pick up anything ?
# okay . what do you want ?
# know you applied to u .s .c . .
# that is amazing congratulations . good for you .
# okay .
# well maybe you know your luck it is just down and the market for your particular field is down and maybe you just need to look into doing something else for a while .
# don t be stupid .
# because you can t feel like that anymore chris you hear me ? i mean everything that you have you deserve . and that includes me . and your father ? your father put hundreds of planes in the air you should be proud . a man should be paid for that .
# spring s nice though .
# oh .
# professional softball player malibu . laughter
# i m so stupid . i m like a little kid . i it s amazing i get out of the house with my fly zipped . oh laughter .
# they sting .
# fuck boston .
# the national guard is i guess really spread thin and then everyone has to go . we all have to go back my whole companies going back .
# i just

# %%
text_train['transcription']
# Out:
# 4973    they want me there two years but i could proba...
# 1302                                            laughter
# 1805    they didn t die they killed themselves for eac...
# 149         how do you know he s even thinking about it ?
# 6890    i don t know are you like i don t know . are y...
#                               ...
# 4403    i m so stupid . i m like a little kid . i it s...
# 5999                                         they sting .
# 5134                                        fuck boston .
# 1470    the national guard is i guess really spread th...
# 3860                                              i just
# Name: transcription, Length: 6018, dtype: object

# %%
# Prepare text data
text_train = pd.DataFrame()
text_train['wav_file'] = x_train['wav_file']
text_train['label'] = x_train['label']
text_train['transcription'] = [normalizeString(audiocode2text[code]) for code in x_train['wav_file']]

text_test = pd.DataFrame()
text_test['wav_file'] = x_test['wav_file']
text_test['label'] = x_test['label']
text_test['transcription'] = [normalizeString(audiocode2text[code]) for code in x_test['wav_file']]

text_train.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/text_train.csv', index=False)
text_test.to_csv('/content/drive/My Drive/IEMOCAP/pre-processed/text_test.csv', index=False)

print(text_train.shape, text_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4b6f3a32b9f9> in <module>()
#       1 # Prepare text data
#       2 text_train = pd.DataFrame()
# ----> 3 text_train['wav_file'] = x_train['wav_file']
#       4 text_train['label'] = x_train['label']
#       5 text_train['transcription'] = [normalizeString(audiocode2text[code]) for code in x_train['wav_file']]
#
# NameError: name 'x_train' is not defined

# %%
import pandas as pd
import numpy as np
import pickle

import itertools
import xgboost as xgb
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score

from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns


df_text_train = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/text_train.csv')
df_text_test = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/text_test.csv')
display(df_text_train.head())
# Out:
#                  wav_file  ...                                      transcription
# 0     Ses03M_impro02_M025  ...  they want me there two years but i could proba...
# 1  Ses01F_script03_1_F020  ...                                          laughter
# 2  Ses01M_script01_3_M031  ...  they didn t die they killed themselves for eac...
# 3  Ses01M_script01_2_M003  ...      how do you know he s even thinking about it ?
# 4     Ses04F_impro07_M035  ...  i don t know are you like i don t know . are y...
#
# [5 rows x 3 columns]

# %%
col = ['label', 'transcription']
df_text_train = df_text_train[col]
df_text_test = df_text_test[col]

# %%
df_text_train.columns
# Out:
# Index(['label', 'transcription'], dtype='object')

# %%
df_text_train.columns = ['label', 'transcription']
df_text_test.columns = ['label', 'transcription']

# %%
category_to_id = {'ang': 0,
                'hap': 1,
                'sad': 2,
                'fea': 3,
                'sur': 4,
                'neu': 5}
id_to_category = {0: 'ang', 1: 'hap', 2: 'sad', 3: 'fea', 4: 'sur', 5: 'neu'}

# %%
fig = plt.figure(figsize=(8,6))
df_text_train.groupby('label').transcription.count().plot.bar(ylim=0)
plt.show()

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(df_text.transcription).toarray()

labels = df_text.label
print(features.shape)
# Out:
# (7523, 2309)

# %%
x_test
# Out:
#                      wav_file  label  ...  auto_corr_max  auto_corr_std
# 5654      Ses03M_impro06_M020      2  ...       0.000032       0.000036
# 4747      Ses03F_impro02_F032      2  ...       0.000017       0.000010
# 7853      Ses04M_impro06_M007      2  ...       0.000090       0.000153
# 5529      Ses03M_impro04_M004      0  ...       0.001004       0.000461
# 1716   Ses01M_script03_1_M016      1  ...       0.014253       0.018849
# ...                       ...    ...  ...            ...            ...
# 9049   Ses05M_script03_2_F040      0  ...       0.136263       0.079161
# 5296   Ses03F_script03_1_F002      3  ...       0.000289       0.000249
# 10015     Ses05F_impro01_M009      2  ...       0.001367       0.001703
# 2939   Ses02F_script03_2_M034      2  ...       0.001865       0.001285
# 6308      Ses04F_impro04_F020      2  ...       0.007443       0.006610
#
# [1505 rows x 10 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.20)
# count_vect = CountVectorizer()
# x_train_counts = count_vect.fit_transform(x_train)
# tfidf_transformer = TfidfTransformer()
# x_train_tfidf = tfidf_transformer.fit_transform(x_train_counts)

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'sad': 2,
                'fea': 3,
                'sur': 4,
                'neu': 5}

emo_keys = list(['ang', 'hap', 'sad', 'fea', 'sur', 'neu'])

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    # plt.figure(figsize=(8,8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def one_hot_encoder(true_labels, num_records, num_classes):
    temp = np.array(true_labels[:num_records])
    true_labels = np.zeros((num_records, num_classes))
    true_labels[np.arange(num_records), temp] = 1
    return true_labels

def display_results(y_test, pred_probs, cm=True):
    pred = np.argmax(pred_probs, axis=-1)
    one_hot_true = one_hot_encoder(y_test, len(pred), len(emotion_dict))
    print('Test Set Accuracy =  {0:.3f}'.format(accuracy_score(y_test, pred)))
    print('Test Set F-score =  {0:.3f}'.format(f1_score(y_test, pred, average='macro')))
    print('Test Set Precision =  {0:.3f}'.format(precision_score(y_test, pred, average='macro')))
    print('Test Set Recall =  {0:.3f}'.format(recall_score(y_test, pred, average='macro')))
    if cm:
        plot_confusion_matrix(confusion_matrix(y_test, pred), classes=emo_keys)

# %%
y_train = x_train['label']
y_test = x_test['label']

# %%
x_train[x_train['wav_file'] == 'Ses03M_impro02_M025']
# Out:
#                  wav_file  label  ...  auto_corr_max  auto_corr_std
# 4973  Ses03M_impro02_M025      2  ...       0.000202       0.000147
#
# [1 rows x 10 columns]

# %%
rf_classifier = RandomForestClassifier(n_estimators=600, min_samples_split=25)
rf_classifier.fit(x_train.drop(columns=['label','wav_file']), y_train)

# Predict
pred_probs = rf_classifier.predict_proba(x_test.drop(columns=['label','wav_file']))

# Results
display_results(y_test, pred_probs)

with open('/content/drive/My Drive/IEMOCAP/pre-processed/text_rf_classifier.pkl', 'wb') as f:
    pickle.dump(pred_probs, f)
# Out:
# Test Set Accuracy =  0.437
# Test Set F-score =  0.248
# Test Set Precision =  0.273
# Test Set Recall =  0.251
# Confusion matrix, without normalization
# [[ 74  44  97   0   0  16]
#  [ 41  57 176   0   0  43]
#  [ 31  48 439   0   0  72]
#  [  0   0   9   0   0   2]
#  [  2   1  17   0   0   0]
#  [ 17  21 211   0   0  87]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import pickle
import matplotlib
import matplotlib.pyplot as plt
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.utils.class_weight import compute_class_weight
import itertools
from IPython.display import display

# %matplotlib inline

# %%
x_train = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_train.csv')
x_test = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_test.csv')

print(x_train.shape)
y_train = x_train['label']
y_test = x_test['label']

# %%
print(x_train.shape, x_test.shape)
cl_weight = dict(pd.Series(x_train['label']).value_counts(normalize=True))
print(dict(pd.Series(x_train['label']).value_counts()))

#del x_train['label']
#del x_test['label']
#del x_train['wav_file']
#del x_test['wav_file']

# %%
rf_classifier = RandomForestClassifier(n_estimators=1200, min_samples_split=25)
rf_classifier.fit(x_train, y_train)

# Predict
pred_probs = rf_classifier.predict_proba(x_test)

# Results
display_results(y_test, pred_probs)

with open('/content/drive/My Drive/IEMOCAP/pre-processed/rf_classifier.pkl', 'wb') as f:
    pickle.dump(pred_probs, f)

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix

# %%
x_train_cnn = x_train.drop(columns=['label','wav_file'])
x_test_cnn = x_test.drop(columns=['label','wav_file'])

# %%
x_train_cnn
# Out:
#       sig_mean   sig_std  rmse_mean  ...  harmonic  auto_corr_max  auto_corr_std
# 4973  0.008187  0.010855   0.008468  ...  0.169062       0.000202       0.000147
# 1302  0.072491  0.090118   0.074097  ...  0.169127       0.010447       0.008435
# 1805  0.027375  0.035375   0.028102  ...  0.169007       0.001753       0.002317
# 149   0.046962  0.066705   0.047804  ...  0.169511       0.006278       0.006828
# 6890  0.012793  0.015674   0.013023  ...  0.168405       0.000372       0.000329
# ...        ...       ...        ...  ...       ...            ...            ...
# 4403  0.012898  0.018825   0.013616  ...  0.169031       0.000571       0.000612
# 5999  0.049667  0.056282   0.051874  ...  0.168587       0.003879       0.001471
# 5134  0.014850  0.024299   0.016224  ...  0.168654       0.000965       0.000292
# 1470  0.021340  0.025361   0.022095  ...  0.168681       0.000882       0.001801
# 3860  0.013490  0.024203   0.013925  ...  0.168756       0.000989       0.000821
#
# [6018 rows x 8 columns]

# %%
x_train_cnn = x_train_cnn.values.reshape(x_train_cnn.shape[0],x_train_cnn.shape[1],1)
x_test_cnn = x_test_cnn.values.reshape(x_test_cnn.shape[0],x_test_cnn.shape[1],1)

# %%
x_train_cnn
# Out:
# array([[[8.18693707e-03],
#         [1.08547071e-02],
#         [8.46753986e-03],
#         ...,
#         [1.69061977e-01],
#         [2.02018004e-04],
#         [1.47191629e-04]],
#
#        [[7.24911339e-02],
#         [9.01175938e-02],
#         [7.40974819e-02],
#         ...,
#         [1.69127311e-01],
#         [1.04472022e-02],
#         [8.43514230e-03]],
#
#        [[2.73745952e-02],
#         [3.53748600e-02],
#         [2.81024164e-02],
#         ...,
#         [1.69007279e-01],
#         [1.75319423e-03],
#         [2.31690263e-03]],
#
#        ...,
#
#        [[1.48501060e-02],
#         [2.42985845e-02],
#         [1.62235381e-02],
#         ...,
#         [1.68654076e-01],
#         [9.65311435e-04],
#         [2.91668613e-04]],
#
#        [[2.13397407e-02],
#         [2.53605630e-02],
#         [2.20948805e-02],
#         ...,
#         [1.68681011e-01],
#         [8.82149563e-04],
#         [1.80050440e-03]],
#
#        [[1.34897015e-02],
#         [2.42029849e-02],
#         [1.39253538e-02],
#         ...,
#         [1.68756002e-01],
#         [9.88904077e-04],
#         [8.21457595e-04]]])

# %%
model = Sequential()
model.add(Conv1D(254,5,padding='same',input_shape=(x_train_cnn[0].shape))) # there are 8 features
model.add(Activation('relu'))
model.add(Conv1D(128,5,padding='same'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128,5,padding='same'))
model.add(Activation('relu'))
model.add(Conv1D(128,5,padding='same'))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(6))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.RMSprop(learning_rate=0.001, decay=1e-4)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 8, 254)            1524
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 254)            0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 8, 128)            162688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 128)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 1, 128)            82048
# _________________________________________________________________
# activation_12 (Activation)   (None, 1, 128)            0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 1, 128)            82048
# _________________________________________________________________
# activation_13 (Activation)   (None, 1, 128)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 774
# _________________________________________________________________
# activation_14 (Activation)   (None, 6)                 0
# =================================================================
# Total params: 329,082
# Trainable params: 329,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer=opt, metrics=['accuracy'])

# %%
cnn_model_hist = model.fit(x_train_cnn, y_train, batch_size=20,epochs=20, validation_data=(x_test_cnn,y_test))
# Out:
# Epoch 1/20
# 301/301 [==============================] - 7s 20ms/step - loss: 1.3826 - accuracy: 0.3966 - val_loss: 1.3533 - val_accuracy: 0.4206
# Epoch 2/20
# 301/301 [==============================] - 6s 20ms/step - loss: 1.3396 - accuracy: 0.4103 - val_loss: 1.3599 - val_accuracy: 0.4073
# Epoch 3/20
# 301/301 [==============================] - 6s 19ms/step - loss: 1.3320 - accuracy: 0.4066 - val_loss: 1.3460 - val_accuracy: 0.4199
# Epoch 4/20
))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def one_hot_encoder(true_labels, num_records, num_classes):
    temp = np.array(true_labels[:num_records])
    true_labels = np.zeros((num_records, num_classes))
    true_labels[np.arange(num_records), temp] = 1
    return true_labels

def display_results(y_test, pred_probs, cm=True):
    pred = np.argmax(pred_probs, axis=-1)
    one_hot_true = one_hot_encoder(y_test, len(pred), len(emotion_dict_new))
    print('Test Set Accuracy =  {0:.3f}'.format(accuracy_score(y_test, pred)))
    print('Test Set F-score =  {0:.3f}'.format(f1_score(y_test, pred, average='macro')))
    print('Test Set Precision =  {0:.3f}'.format(precision_score(y_test, pred, average='macro')))
    print('Test Set Recall =  {0:.3f}'.format(recall_score(y_test, pred, average='macro')))
    if cm:
        plot_confusion_matrix(confusion_matrix(y_test, pred), classes=emo_keys)

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import pickle
import matplotlib
import matplotlib.pyplot as plt
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.utils.class_weight import compute_class_weight
import itertools
from IPython.display import display

# %matplotlib inline

# %%
x_train_mfcc = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_train_mfcc.csv')
x_test_mfcc = pd.read_csv('/content/drive/My Drive/IEMOCAP/pre-processed/audio_test_mfcc.csv')

print(x_train_mfcc.shape)
y_train_mfcc = x_train_mfcc['label']
y_test_mfcc = x_test_mfcc['label']
# Out:
# (6018, 182)

# %%
print(x_train_mfcc.shape, x_test_mfcc.shape)
cl_weight_mfcc = dict(pd.Series(x_train_mfcc['label']).value_counts(normalize=True))
print(dict(pd.Series(x_train_mfcc['label']).value_counts()))

#del x_train['label']
#del x_test['label']
#del x_train['wav_file']
#del x_test['wav_file']
# Out:
# (6018, 182) (1505, 182)
# {2: 2372, 5: 1371, 1: 1286, 0: 872, 4: 83, 3: 34}

# %%
rf_classifier_mfcc = RandomForestClassifier(n_estimators=1200, min_samples_split=25)
rf_classifier_mfcc.fit(x_train_mfcc.drop(columns=['wav_file','label']), y_train_mfcc)

# Predict
pred_probs_mfcc = rf_classifier_mfcc.predict_proba(x_test_mfcc.drop(columns=['wav_file','label']))

# Results
display_results(y_test_mfcc, pred_probs_mfcc)

with open('/content/drive/My Drive/IEMOCAP/pre-processed/rf_classifier_mfcc.pkl', 'wb') as f:
    pickle.dump(pred_probs_mfcc, f)
# Out:
# Test Set Accuracy =  0.500
# Test Set F-score =  0.307
# Test Set Precision =  0.342
# Test Set Recall =  0.303
# Confusion matrix, without normalization
# [[ 87  18 109   0   0  15]
#  [ 31 108 150   0   0  61]
#  [ 37  36 442   0   0  44]
#  [  0   2   3   0   0   1]
#  [  4   4   8   0   0   8]
#  [  7  23 192   0   0 115]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D,Conv2D, MaxPooling2D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix

# %%
x_train_mfcc_cnn = x_train_mfcc.drop(columns=['label','wav_file'])
x_test_mfcc_cnn = x_test_mfcc.drop(columns=['label','wav_file'])

# %%
type(x_train_mfcc_cnn)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train_mfcc_cnn = x_train_mfcc_cnn.values.reshape(x_train_mfcc_cnn.shape[0],x_train_mfcc_cnn.shape[1],1)
x_test_mfcc_cnn = x_test_mfcc_cnn.values.reshape(x_test_mfcc_cnn.shape[0],x_test_mfcc_cnn.shape[1],1)

# %%
x_train_mfcc_cnn
# Out:
# array([[[ 0.69938223],
#         [-1.96401262],
#         [ 0.25166201],
#         ...,
#         [-0.0353848 ],
#         [-0.03540364],
#         [-0.03541539]],
#
#        [[ 1.77231654],
#         [ 0.60048549],
#         [-1.80452134],
#         ...,
#         [-0.0271964 ],
#         [-0.02721424],
#         [-0.02722518]],
#
#        [[-0.88349785],
#         [-0.02927129],
#         [ 2.05666701],
#         ...,
#         [-0.0357663 ],
#         [-0.03578407],
#         [-0.03579519]],
#
#        ...,
#
#        [[-1.811963  ],
#         [ 1.1809182 ],
#         [-0.0964529 ],
#         ...,
#         [-0.03585737],
#         [-0.03587513],
#         [-0.03588624]],
#
#        [[-0.0435452 ],
#         [-0.97765974],
#         [ 0.21496183],
#         ...,
#         [-0.03585133],
#         [-0.035869  ],
#         [-0.03588005]],
#
#        [[ 1.16000059],
#         [ 0.98044208],
#         [-0.79670317],
#         ...,
#         [-0.03419319],
#         [-0.03421188],
#         [-0.03422356]]])

# %%
model_mfcc = Sequential()
model_mfcc.add(Conv1D(254,5,padding='same',input_shape=(x_train_mfcc_cnn[0].shape))) # there are 8 features
model_mfcc.add(Activation('relu'))
model_mfcc.add(Conv1D(128,5,padding='same'))
model_mfcc.add(Dropout(0.1))
model_mfcc.add(MaxPooling1D(pool_size=(8)))
model_mfcc.add(Conv1D(128,5,padding='same'))
model_mfcc.add(Activation('relu'))
model_mfcc.add(Conv1D(128,5,padding='same'))
model_mfcc.add(Activation('relu'))
model_mfcc.add(Flatten())
model_mfcc.add(Dense(6))
model_mfcc.add(Activation('softmax'))
opt = tf.keras.optimizers.RMSprop(learning_rate=0.001, decay=1e-4)

# %%
model_mfcc.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 180, 254)          1524
# _________________________________________________________________
# activation (Activation)      (None, 180, 254)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 180, 128)          162688
# _________________________________________________________________
# dropout (Dropout)            (None, 180, 128)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 22, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 22, 128)           82048
# _________________________________________________________________
# activation_1 (Activation)    (None, 22, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 22, 128)           82048
# _________________________________________________________________
# activation_2 (Activation)    (None, 22, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 2816)              0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 16902
# _________________________________________________________________
# activation_3 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 345,210
# Trainable params: 345,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_mfcc.compile(loss='sparse_categorical_crossentropy',optimizer=opt, metrics=['accuracy'])

# %%
cnn_model_mfcc_hist = model_mfcc.fit(x_train_mfcc_cnn, y_train_mfcc, batch_size=20,epochs=30, validation_data=(x_test_mfcc_cnn,y_test_mfcc))
# Out:
# Epoch 1/30
# 301/301 [==============================] - 37s 124ms/step - loss: 1.2040 - accuracy: 0.4998 - val_loss: 1.4087 - val_accuracy: 0.4645
# Epoch 2/30
# 301/301 [==============================] - 37s 124ms/step - loss: 1.1619 - accuracy: 0.5224 - val_loss: 1.4024 - val_accuracy: 0.4645
# Epoch 3/30
# 301/301 [==============================] - 38s 125ms/step - loss: 1.1267 - accuracy: 0.5427 - val_loss: 1.6223 - val_accuracy: 0.4817
# Epoch 4/30
# 301/301 [==============================] - 38s 125ms/step - loss: 1.0778 - accuracy: 0.5656 - val_loss: 1.4428 - val_accuracy: 0.4837
# Epoch 5/30
# Epoch 25/30
# 301/301 [==============================] - 37s 123ms/step - loss: 0.1566 - accuracy: 0.9485 - val_loss: 8.6944 - val_accuracy: 0.4744
# Epoch 26/30
# 301/301 [==============================] - 37s 123ms/step - loss: 0.1575 - accuracy: 0.9458 - val_loss: 9.1616 - val_accuracy: 0.4591
# Epoch 27/30
# 301/301 [==============================] - 37s 123ms/step - loss: 0.1449 - accuracy: 0.9551 - val_loss: 9.5968 - val_accuracy: 0.4525
# Epoch 28/30
# 301/301 [==============================] - 37s 124ms/step - loss: 0.1337 - accuracy: 0.9555 - val_loss: 10.9670 - val_accuracy: 0.4718
# Epoch 29/30
# 301/301 [==============================] - 38s 125ms/step - loss: 0.1355 - accuracy: 0.9575 - val_loss: 9.8161 - val_accuracy: 0.4698
# Epoch 30/30
# 301/301 [==============================] - 38s 126ms/step - loss: 0.1298 - accuracy: 0.9548 - val_loss: 10.7196 - val_accuracy: 0.4658

# %%
cnn_model_mfcc_hist

# %%
### Create an output directory
output_dir = '/content/drive/My Drive/IEMOCAP/model_outputs'
if not os.path.exists(output_dir): ### If the file directory doesn't already exists,
    os.makedirs(output_dir) ### Make it please

# %%
x_train_mfcc_cnn_2d = np.expand_dims(x_train_mfcc_cnn, -1)
x_test_mfcc_cnn_2d = np.expand_dims(x_test_mfcc_cnn, -1)

# %%
x_train_mfcc_cnn_2d.shape
# Out:
# (6018, 180, 1, 1)

# %%
ip = tf.keras.layers.Input(shape=x_train_mfcc_cnn[0].shape)

model_mfcc_2d = Sequential()
model_mfcc_2d.add(Conv2D(256,5,padding='same',input_shape=(180,1,1))) #(x_train_mfcc_cnn_2d[0].shape))) # there are 8 features
model_mfcc_2d.add(Activation('relu'))
model_mfcc_2d.add(Conv2D(128,5,padding='same'))
model_mfcc_2d.add(Dropout(0.1))
#model_mfcc_2d.add(MaxPooling2D(pool_size=(2)))
model_mfcc_2d.add(Conv2D(128,5,padding='same'))
model_mfcc_2d.add(Activation('relu'))
model_mfcc_2d.add(Flatten())
model_mfcc_2d.add(Dense(6))
model_mfcc_2d.add(Activation('softmax'))
#opt = tf.keras.optimizers.RMSprop(learning_rate=0.001, decay=1e-4)

# m_2d = tf.keras.layers.Conv2D(256, kernel_size=1, activation='relu')(ip)
# m_2d = tf.keras.layers.MaxPooling2D(pool_size=2)(m_2d)
# m_2d = tf.keras.layers.BatchNormalization()(m_2d)
# m_2d = tf.keras.layers.Dropout(0.2)(m_2d)
# m_2d = tf.keras.layers.Flatten()(m_2d)
# m_2d = tf.keras.layers.Dense(64, activation='relu')(m_2d)
# m_2d = tf.keras.layers.Dense(32, activation='relu')(m_2d)
# op = tf.keras.layers.Dense(6, activation='softmax')(m_2d)
# model_2d = tf.keras.Model(inputs=ip, outputs=op)
# #checkpoint_path = "cp.ckpt"
# Create a callback that saves the model's weights
#cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_best_only=True,
#                                                 mode='max',
#                                                 monitor='val_accuracy',
#                                                 verbose=1)

# %%
model_mfcc_2d.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 180, 1, 256)       6656
# _________________________________________________________________
# activation_8 (Activation)    (None, 180, 1, 256)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 180, 1, 128)       819328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 180, 1, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 180, 1, 128)       409728
# _________________________________________________________________
# activation_9 (Activation)    (None, 180, 1, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 23040)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 138246
# _________________________________________________________________
# activation_10 (Activation)   (None, 6)                 0
# =================================================================
# Total params: 1,373,958
# Trainable params: 1,373,958
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %%
model_checkpoint = ModelCheckpoint(filepath=output_dir+'/cnn2d_weights.{epoch:02d}.hdf5',
                                  save_weights_only=True)

early_stopping = EarlyStopping(patience=3, # Stop after 3 epochs of no improvement
                               monitor='val_loss', # Look at validation_loss
                               min_delta=0, # After 0 change
                               mode='min', # Stop when quantity has stopped decreasing
                               restore_best_weights=False, # Don't Restore the best weights
                               verbose=1) 

reduce_lr = ReduceLROnPlateau(monitor='val_loss', # Look at validation loss
                              min_lr=0.000001, # Lower bound of learning rate
                              patience=1, # Reduce after 1 with little change
                              mode='min', # Stop when quantity has stopped decreasing
                              factor=0.1, # Reduce by a factor of 1/10
                              min_delta=0.01, # Minimumn change needed
                              verbose=1)

# %%
model_mfcc_2d.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
history_mfcc_2d = model_mfcc_2d.fit(x_train_mfcc_cnn_2d, 
              y_train_mfcc,
              epochs=10,
              batch_size=32,
              validation_data=(x_test_mfcc_cnn_2d, y_test_mfcc),
              callbacks=[model_checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/10
# 189/189 [==============================] - 209s 1s/step - loss: 1.1764 - accuracy: 0.5113 - val_loss: 1.2450 - val_accuracy: 0.4777
# Epoch 2/10
# 189/189 [==============================] - 209s 1s/step - loss: 1.1241 - accuracy: 0.5351 - val_loss: 1.2953 - val_accuracy: 0.4957
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 3/10
# 189/189 [==============================] - 208s 1s/step - loss: 1.0378 - accuracy: 0.5748 - val_loss: 1.2519 - val_accuracy: 0.4924
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 4/10
# 189/189 [==============================] - 209s 1s/step - loss: 1.0067 - accuracy: 0.5934 - val_loss: 1.2565 - val_accuracy: 0.4957
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00004: early stopping

# %%
x_train_mfcc_cnn_2d = np.expand_dims(x_train_mfcc_cnn, -1)
x_test_mfcc_cnn_2d = np.expand_dims(x_test_mfcc_cnn, -1)

# %%
x_train_mfcc_cnn_2d.shape
# Out:
# (6018, 180, 1, 1)

# %%
ip = tf.keras.layers.Input(shape=x_train_mfcc_cnn[0].shape)

# %%
ip
# Out:
# <KerasTensor: shape=(None, 180, 1) dtype=float32 (created by layer 'input_9')>

# %%
ip = tf.keras.layers.Input(shape=x_train_mfcc_cnn[0].shape)

m_2d = tf.keras.layers.Conv2D(256, kernel_size=1, activation='relu',input_shape = (180,1))
m_2d = tf.keras.layers.MaxPooling2D(pool_size=2)(m_2d)
m_2d = tf.keras.layers.BatchNormalization()(m_2d)
m_2d = tf.keras.layers.Dropout(0.2)(m_2d)
m_2d = tf.keras.layers.Flatten()(m_2d)
m_2d = tf.keras.layers.Dense(64, activation='relu')(m_2d)
m_2d = tf.keras.layers.Dense(32, activation='relu')(m_2d)
op = tf.keras.layers.Dense(6, activation='softmax')(m_2d)
model_2d = tf.keras.Model(inputs=ip, outputs=op)
#checkpoint_path = "cp.ckpt"
# Create a callback that saves the model's weights
#cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_best_only=True,
#                                                 mode='max',
#                                                 monitor='val_accuracy',
#                                                 verbose=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-f86bf2b16fc9> in <module>()
#       2
#       3 m_2d = tf.keras.layers.Conv2D(256, kernel_size=1, activation='relu',input_shape = (180,1))
# ----> 4 m_2d = tf.keras.layers.MaxPooling2D(pool_size=2)(m_2d)
#       5 m_2d = tf.keras.layers.BatchNormalization()(m_2d)
#       6 m_2d = tf.keras.layers.Dropout(0.2)(m_2d)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1018         training=training_mode):
#    1019
# -> 1020       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1021       if eager:
#    1022         call_fn = self.call
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194     # have a `shape` attribute.
#     195     if not hasattr(x, 'shape'):
# --> 196       raise TypeError('Inputs to a layer should be tensors. Got: %s' % (x,))
#     197
#     198   if len(inputs) != len(input_spec):
#
# TypeError: Inputs to a layer should be tensors. Got: <keras.layers.convolutional.Conv2D object at 0x7f68b6916b10>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %%
model_checkpoint = ModelCheckpoint(filepath=output_dir+'/cnn2d_weights.{epoch:02d}.hdf5',
                                  save_weights_only=True)

early_stopping = EarlyStopping(patience=3, # Stop after 3 epochs of no improvement
                               monitor='val_loss', # Look at validation_loss
                               min_delta=0, # After 0 change
                               mode='min', # Stop when quantity has stopped decreasing
                               restore_best_weights=False, # Don't Restore the best weights
                               verbose=1) 

reduce_lr = ReduceLROnPlateau(monitor='val_loss', # Look at validation loss
                              min_lr=0.000001, # Lower bound of learning rate
                              patience=1, # Reduce after 1 with little change
                              mode='min', # Stop when quantity has stopped decreasing
                              factor=0.1, # Reduce by a factor of 1/10
                              min_delta=0.01, # Minimumn change needed
                              verbose=1)

# %%
model_2d.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
history_cnn_2d = model_2d.fit(x_train_mfcc_cnn, 
          y_train_mfcc,
          epochs=2,
          batch_size=32,
          validation_data=(x_test_mfcc_cnn, y_test_mfcc),
          callbacks=[model_checkpoint, early_stopping, reduce_lr])

# %%
### BERT

# %%
### BERT

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.10.2-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 4.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 47.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 61.0 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 36.0 MB/s
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.17 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.10.2

# %%
# !pip install --quiet shap==0.39
# Out:
#      |████████████████████████████████| 356 kB 4.0 MB/s
#   Building wheel for shap (setup.py) ... done

# %%
pip import shap
# Out:
# ERROR: unknown command "import"

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import torch
import transformers as ppb
import warnings
warnings.filterwarnings('ignore')

# %%
#df = pd.read_csv('https://github.com/clairett/pytorch-sentiment-classification/raw/master/data/SST2/train.tsv', delimiter='\t', header=None)

# %%
# For DistilBERT:
model_class, tokenizer_class, pretrained_weights = (ppb.DistilBertModel, ppb.DistilBertTokenizer, 'distilbert-base-uncased')

## Want BERT instead of distilBERT? Uncomment the following line:
#model_class, tokenizer_class, pretrained_weights = (ppb.BertModel, ppb.BertTokenizer, 'bert-base-uncased')

# Load pretrained model/tokenizer
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model_bert = model_class.from_pretrained(pretrained_weights)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
df_text_train
# Out:
#       label                                      transcription
# 0         2  they want me there two years but i could proba...
# 1         1                                          laughter
# 2         2  they didn t die they killed themselves for eac...
# 3         2      how do you know he s even thinking about it ?
# 4         5  i don t know are you like i don t know . are y...
# ...     ...                                                ...
# 6013      1  i m so stupid . i m like a little kid . i it s...
# 6014      2                                       they sting .
# 6015      5                                      fuck boston .
# 6016      2  the national guard is i guess really spread th...
# 6017      2                                            i just
#
# [6018 rows x 2 columns]

# %%
max_val = 0
for sent in (df_text_train['transcription'].tolist() + df_text_train['transcription'].tolist() + df_text_test['transcription'].tolist()):
    try:
        sent_tok_len = len(tokenizer.tokenize(sent))
        max_val = sent_tok_len if (sent_tok_len > max_val) else max_val
    except:
        pass
    
print(f"The maximum amount of tokens in the dataset is {max_val}")
# Out:
# The maximum amount of tokens in the dataset is 114

# %%
from transformers import DistilBertTokenizer, TFDistilBertModel, DistilBertConfig

# %%
MODEL_NAME = 'distilbert-base-cased'

# %%
MAX_LENGTH = 114

tokenizer = DistilBertTokenizer.from_pretrained(MODEL_NAME,  
                                                add_special_tokens=True,
                                                max_length=MAX_LENGTH, 
                                                pad_to_max_length=True)

def tokenize(sentences, tokenizer):
    input_ids, input_masks, input_segments = [], [], []
    for sentence in tqdm(sentences):
        inputs = tokenizer.encode_plus(sentence, 
                                       add_special_tokens=True, 
                                       max_length=MAX_LENGTH, 
                                       pad_to_max_length=True, 
                                       return_attention_mask=True, 
                                       return_token_type_ids=True, 
                                       truncation=True)
        input_ids.append(inputs['input_ids'])
        input_masks.append(inputs['attention_mask'])
        input_segments.append(inputs['token_type_ids'])        
        
    return np.asarray(input_ids, dtype='int32'), np.asarray(input_masks, dtype='int32')
# Out:
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
X_train_text = tokenize(df_text_train['transcription'], tokenizer)
X_test_text = tokenize(df_text_test['transcription'], tokenizer)
X_val_text = tokenize(df_text_test['transcription'], tokenizer)
# Out:
# 100%|██████████| 6018/6018 [00:02<00:00, 2288.98it/s]
# 100%|██████████| 1505/1505 [00:00<00:00, 2208.59it/s]
# 100%|██████████| 1505/1505 [00:00<00:00, 2261.49it/s]

# %%
## Creating an entry

# %%
config = DistilBertConfig.from_pretrained(MODEL_NAME, output_hidden_states=True, output_attentions=True)
DistilBERT = TFDistilBertModel.from_pretrained(MODEL_NAME, config=config)

input_ids_in = tf.keras.layers.Input(shape=(MAX_LENGTH,), name='input_token', dtype='int32')
input_masks_in = tf.keras.layers.Input(shape=(MAX_LENGTH,), name='masked_token', dtype='int32') 

embedding_layer = DistilBERT(input_ids = input_ids_in, attention_mask = input_masks_in)[0]
X = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True))(embedding_layer)
X = tf.keras.layers.GlobalMaxPool1D()(X)
X = tf.keras.layers.Dense(64, activation='relu')(X)
X = tf.keras.layers.Dropout(0.2)(X)
X = tf.keras.layers.Dense(6, activation='softmax')(X)

model_bert_local = tf.keras.Model(inputs=[input_ids_in, input_masks_in], outputs = X)

for layer in model_bert_local.layers[:3]:
    layer.trainable = False

model_bert_local.summary()
# Out:
# Some layers from the model checkpoint at distilbert-base-cased were not used when initializing TFDistilBertModel: ['vocab_transform', 'vocab_layer_norm', 'vocab_projector', 'activation_13']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_token (InputLayer)        [(None, 114)]        0
# __________________________________________________________________________________________________
# masked_token (InputLayer)       [(None, 114)]        0
# __________________________________________________________________________________________________
# tf_distil_bert_model_3 (TFDisti TFBaseModelOutput(la 65190912    input_token[0][0]
#                                                                  masked_token[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 114, 256)     918528      tf_distil_bert_model_3[0][13]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 256)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           16448       global_max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 6)            390         dropout_78[0][0]
# ==================================================================================================
# Total params: 66,126,278
# Trainable params: 935,366
# Non-trainable params: 65,190,912
# __________________________________________________________________________________________________

# %%
### Create an output directory
output_dir = '/content/drive/My Drive/IEMOCAP/model_outputs'
if not os.path.exists(output_dir): ### If the file directory doesn't already exists,
    os.makedirs(output_dir) ### Make it please

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %%
model_checkpoint = ModelCheckpoint(filepath=output_dir+'/weights.{epoch:02d}.hdf5',
                                  save_weights_only=True)

early_stopping = EarlyStopping(patience=3, # Stop after 3 epochs of no improvement
                               monitor='val_loss', # Look at validation_loss
                               min_delta=0, # After 0 change
                               mode='min', # Stop when quantity has stopped decreasing
                               restore_best_weights=False, # Don't Restore the best weights
                               verbose=1) 

reduce_lr = ReduceLROnPlateau(monitor='val_loss', # Look at validation loss
                              min_lr=0.000001, # Lower bound of learning rate
                              patience=1, # Reduce after 1 with little change
                              mode='min', # Stop when quantity has stopped decreasing
                              factor=0.1, # Reduce by a factor of 1/10
                              min_delta=0.01, # Minimumn change needed
                              verbose=1)

# %%
y_train_text = df_text_train['label']
y_test_text = df_text_test['label']

# %%
model_bert_local.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model_bert_local.fit(X_train_text, 
                    y_train_text, 
                    epochs = 1,
                    batch_size=16, 
                    validation_data=(X_test_text, y_test_text), 
                    callbacks=[model_checkpoint, early_stopping, reduce_lr])
# Out:
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 377/377 [==============================] - ETA: 0s - loss: 1.3095 - accuracy: 0.4430WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 377/377 [==============================] - 1758s 5s/step - loss: 1.3095 - accuracy: 0.4430 - val_loss: 1.1854 - val_accuracy: 0.5043

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    print("Lowest Validation Loss: epoch {}".format(np.argmin(val_loss)+1))
    print("Highest Validation Accuracy: epoch {}".format(np.argmax(val_acc)+1))

plot_history(history)

# %%
y_test_probs = model.predict(X_test)

# Turn probabilities into an interger prediction
y_hat = []
for prob in y_test_probs:
    y_hat.append(np.argmax(prob))

# %%
tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True))) ???

# %%
max_len = 0
for i in tokenized.values:
    if len(i) > max_len:
        max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])

# %%
attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape

# %%
input_ids = torch.tensor(padded)  
attention_mask = torch.tensor(attention_mask)

with torch.no_grad():
    last_hidden_states = model_bert(input_ids, attention_mask=attention_mask)

# %%
path = '/content/drive/My Drive/IEMOCAP/No_Videos/IEMOCAP_full_release/Session1/sentences/wav/'
my_list = []
for subdir,dir,files in os.walk(path):
  for file in files:
    try:
      X, sample_rate = librosa.load(os.path.join(subdir,file), res_type = 'kaiser_fast')
      xfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
      file = int(file[6:8])
      arr = xfccs, file 
      my_list.append(arr)
    except ValueError or NoBackendError :
      continue
